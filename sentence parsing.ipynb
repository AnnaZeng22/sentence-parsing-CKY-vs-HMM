# %% [markdown]
# # Part 1

# %% [markdown]
# Write a Python function called cky() that implements the CKY algorithm. This function should return True if words can be successfully parsed into a sentence and False otherwise.

# %%
def cky(words, grammar):

  #initiate the 5*6 table
  table = [[[] for _ in range(len(words) + 1)] for _ in range(len(words))]

  # outer loop
  for j in range(1, len(words) + 1):
    for key, value in grammar.items():
      if words[j-1] in value:
        table[j-1][j].append(key)

        # check (i,k) and (k,j) to fill (i,j)
        for i in range(j-2, -1, -1):
            for k in range(i+1, j):
              for a in table[i][k]:
                for b in table[k][j]:
                  combination = []
                  combination.append(a)
                  combination.append(b)
                  for key, value in grammar.items():
                    if combination in value:
                      table[i][j].append(key)

  # check (0,j)
  if 'S' in table[0][j]:
    return True
  else:
    return False


  ### OUTPUT CHECK ###
  # return True is words can be parsed into a sentence and False otherwise
  #return 'this is just a placeholder'
words = []
words = 'the cat tolerate a dog'.split()#sample, input any words string here##
grammar = {"NP" : [["D", "N"], "cats", "dogs"],
           "VP" : [["V", "NP"], "walk", "sleep"],
           "S"  : [["NP", "VP"]],
           "D"  : ["the", "a"],
           "N"  : ["cat", "dog"],
           "V"  : ["love", "tolerate"]
           }#sample, input any grammar here
cky(words,grammar)
# Out:
# True

# %% [markdown]
# Parse the a large CFG (rules.txt) into a dictionary.

# %%
def cfg(lines):
    grammar = {}
    for line in lines:
        parts = line.split("➡️")
        key = parts[0].strip()
        if "🦖" in parts[1]:
          value = [part.strip() for part in parts[1].split("🦖")]
        else:
          value = parts[1].strip()

        if key in grammar:
          if value not in grammar[key]:
            grammar[key].append(value)
        else:
            grammar[key] = [value]

    return grammar

cfg(open('rules.txt'))
# Out:
# {'S': [['NP', 'S|<VP-.>'],
#   ['S', 'S|<,-NP-VP-.>'],
#   ['NP', 'VP'],
#   ['SBAR', 'S|<,-NP-VP-.>'],
#   ['NP', "S|<VP-.-''>"],
#   ['PP', 'S|<,-NP-VP>'],
#   ['PP', 'S|<,-NP-VP-.>'],
#   ['NP', 'S|<ADVP-VP>'],
#   ['``', 'S|<CC-NP-VP-.>'],
#   ['ADVP', 'S|<PRN-NP-``-VP-.>'],
#   ['NP', 'S|<,-PP-,-VP-.>'],
#   ['ADVP', 'S|<,-NP-VP-.>'],
#   ['S', 'S|<:-S-.>'],
#   ['SBAR', 'S|<,-NP-VP>'],
#   ['S', 'S|<,-CC-S-.>'],
#   ['PP', 'S|<NP-VP-.>'],
#   ['SBAR', 'S|<,-NP-ADVP-VP-.>'],
#   ['CC', 'S|<NP-VP-.>'],
#   ['NP', 'S|<,-PP-,-NP-VP-.>'],
#   ['S', 'S|<,-IN-S-.>'],
#   ['ADVP', 'S|<,-PP-,-NP-VP-.>'],
#   ['S+NP', 'S|<,-NP-VP-.>'],
#   ['NP', 'S|<,-NP-VP-.>'],
#   ['S+VP', 'S|<,-NP-VP-.>'],
#   ['CC', 'S|<PP-,-NP-VP-.>'],
#   ['NP', 'S|<,-S-,-VP-.>'],
#   ['S', 'S|<:-S-:-S-.>'],
#   ['PP', 'VP'],
#   ['S', 'S|<,-CC-S>'],
#   ['SBAR', 'VP'],
#   ['PP', 'S|<NP-VP>'],
#   ['S', 'S|<CC-S-S>'],
#   ['NP', 'ADVP'],
#   ['ADVP', 'VP'],
#   ['S', 'S|<CC-S-.>'],
#   ['S', 'S|<CC-S>'],
#   ['``', 'S|<SBAR-,-S-,-CC-S-.>'],
#   ['S', "S|<,-''-NP-VP-.>"],
#   ['NP', 'S|<ADVP-VP-.>'],
#   ['ADVP', 'S|<,-SBAR-NP-VP>'],
#   ['``', 'S|<NP-VP-:>'],
#   ['NP', 'S|<,-VP-.>'],
#   ['``', "S|<S-,-''-NP-VP-.>"],
#   ['ADVP', 'S|<NP-VP>'],
#   ['NP', 'S|<:-VP>'],
#   ['S+VP', 'VP'],
#   ['PP', 'S|<NP-,-NP-VP-.>'],
#   ['NP', 'ADJP'],
#   ['NP', 'S|<NP-VP-.>'],
#   ['``', 'S|<NP-VP-.>'],
#   ['NP', 'NP'],
#   ['``', "S|<S-CC-S-.-''>"],
#   ['NP', 'S|<RB-VP>'],
#   ['NP', 'S|<PP-S>'],
#   ['PP', 'S|<,-SBAR-,-NP-VP-.>'],
#   ['ADVP', 'S|<NP-VP-.>'],
#   ['ADVP', 'S|<,-NP-VP>'],
#   ['NP', 'S|<PRN-VP>'],
#   ['S+VP', 'S|<CC-S>'],
#   ['VP', 'PP'],
#   ['-LRB-', 'S|<PP-,-NP-VP-.--RRB->'],
#   ['NP', 'S|<PRN-VP-.>'],
#   ['S+ADJP', 'S|<,-NP-VP-.>'],
#   ['CC', 'S|<NP-PRN-VP-.>'],
#   ['NP', 'S|<PP-VP>'],
#   ['NP', 'S|<,-NP-ADVP-VP-.>'],
#   ['NP', 'PP'],
#   ['PP', "S|<PRN-NP-VP-.-''>"],
#   ['VP', '.'],
#   ['NP+NP', 'S|<VP-.>'],
#   ['S', 'S|<:-SBARQ>'],
#   ['NP', 'S|<VP-,>'],
#   ['SBAR', 'S|<PRN-S-CC-S-.>'],
#   ['SBAR', 'S|<VP-.>'],
#   ['PP', 'S|<,-NP-ADVP-VP-.>'],
#   ['NP', 'S|<NP-VP>'],
#   ['CC', 'S|<NP-ADVP-VP>'],
#   ['NP+NP', 'VP'],
#   ['ADJP', 'S|<,-NP-VP-.>'],
#   ['NP', 'S|<,-ADVP-,-ADVP-VP-.>'],
#   ['``', "S|<SBARQ-''-NP-VP-.>"],
#   ['``', "S|<NP-VP-.-''>"],
#   ['CC', 'S|<NP-VP-:-S-.>'],
#   ['NP+NP', 'S|<PRN-VP>'],
#   ['PP', 'S|<,-S-CC-S>'],
#   ['SBAR', "S|<,-NP-VP-.-''>"],
#   ['``', "S|<NP-''-VP>"],
#   ['PP', "S|<,-NP-VP-.-''>"],
#   ['CC', 'S|<ADVP-,-NP-VP>'],
#   ['S', 'S|<:-S-:-S-:-S>'],
#   ['``', "S|<NP-''-VP-.>"],
#   ['CC', 'S|<NP-ADVP-VP-.>'],
#   ['NP+QP', 'S|<VP-.>'],
#   ['PP', 'S|<,-NP-PRN-VP-.>'],
#   ['``', "S|<NP-''-VP-:>"],
#   ['PP', 'S|<,-PP-,-NP-VP-.>'],
#   ['ADVP', 'S|<,-ADVP-,-NP-VP-.>'],
#   ['-LRB-', 'S|<NP-ADVP-VP-.--RRB->'],
#   ['S+VP', 'S|<,-CC-S>'],
#   ['ADVP', "S|<,-SBAR-,-''-NP-VP-.>"],
#   ['S+VP', 'S|<,-VP>'],
#   ['SBAR', 'S|<,-S-:-S-.>'],
#   ['PP', "S|<,-''-VP>"],
#   ['NP', 'S|<,-PP-,-VP>'],
#   ['IN', 'S|<PP-,-NP-VP-.>'],
#   ['``', "S|<ADVP-,-''-PRN-``-NP-VP-.-''>"],
#   ['``', "S|<S-,-''-PRN-S-,-CC-,-S-.>"],
#   ['``', 'S|<NP-VP>'],
#   ['CC', "S|<,-PP-,-NP-VP-.-''>"],
#   ['PP', 'S|<,-ADVP-,-NP-VP-.>'],
#   ['VP', ':'],
#   ['CC', 'S|<ADVP-NP-ADVP-VP-.>'],
#   ['NP', "S|<PRN-ADVP-VP-.-''>"],
#   ['S+VP', 'S|<,-NP-ADVP-VP-.>'],
#   ['CC', 'S|<PRN-NP-VP-.>'],
#   ['CC', 'S|<PRN-S-CC-S-.>'],
#   ['NP', 'S|<PRN-``-VP-.>'],
#   ['ADVP', "S|<,-SBAR-,-NP-VP-.-''>"],
#   ['ADVP', "S|<NP-,-VP-.-''>"],
#   ['S', "S|<,-''-CC-S-.>"],
#   ['``', "S|<VP-.-''>"],
#   ['CC', 'S|<ADVP-NP-VP-.>'],
#   ['S', "S|<,-CC-S-.-''>"],
#   ['NP', 'S|<,-PRN-,-VP>'],
#   ['S', 'S|<,-S-,-CC-S-.>'],
#   ['PP', "S|<,-PP-,-NP-VP-.-''>"],
#   ['PP', 'S|<PRN-NP-VP-.>'],
#   ['NP', "S|<,-''-ADVP-VP>"],
#   ['PP', 'S|<,-S-,-NP-VP-.>'],
#   ['NP', 'S|<``-VP>'],
#   ['PP', 'S|<,-NP-NP-VP-.>'],
#   ['PP', 'S|<,-SBAR-,-NP-VP>'],
#   ['``', "S|<NP-PRN-VP-.-''>"],
#   ['CC', 'S|<S-VP-.>'],
#   ['``', "S|<SBAR-,-NP-VP-.-''>"],
#   ['``', 'S|<NP-VP-:-.>'],
#   ['PP', 'S|<,-NP-VP-:-.>'],
#   ['S', 'S|<,-CC-FRAG-.>'],
#   ['NP+NP', 'S|<NP-S>'],
#   ['``', "S|<RB-NP-VP-.-''>"],
#   ['CC', 'S|<S-,-NP-VP-.>'],
#   ['NP', 'S|<ADVP-``-VP>'],
#   ['NP', 'S|<:-VP-.>'],
#   ['SBAR', 'S|<PRN-NP-VP-.>'],
#   ['``', "S|<S-,-S-,-CC-S-.-''>"],
#   ['ADVP', 'S|<PRN-NP-VP-.>'],
#   ['S+VP', 'S|<ADVP-VP>'],
#   ['NP', "S|<ADVP-VP-.-''>"],
#   ['S', 'S|<:-S>'],
#   ['ADVP', 'S|<,-ADVP-VP>'],
#   ['NP', 'S|<ADVP-ADVP-VP>'],
#   ['NP', 'S|<,-ADVP-,-VP-.>'],
#   ['``', 'S|<S-CC-S-.>'],
#   ['``', "S|<SQ-''-NP-VP-.>"],
#   ['SBAR', "S|<VP-.-''>"],
#   ['``', "S|<S-,-CC-S-.-''>"],
#   ['S+VP', "S|<CC-S-''-CC-S>"],
#   ['CC', 'S|<NP-,-S-,-ADVP-VP-.>'],
#   ['UCP', 'S|<,-NP-VP>'],
#   ['``', 'VP'],
#   ['NP', 'S|<,-VP>'],
#   ['ADVP', 'S|<PP-,-NP-VP-.>'],
#   ['CC', "S|<PP-,-NP-VP-.-''>"],
#   ['S', 'S|<:-CC-S-.>'],
#   ['SBAR', "S|<,-ADVP-NP-VP-.-''>"],
#   ['PP', 'S|<,-PP-PP-,-NP-VP-.>'],
#   ['NP', 'S|<VP-:>'],
#   ['S+VP', "S|<,-''-NP-VP-.>"],
#   ['``', "S|<S-,-''-NP-,-VP-.>"],
#   ['NP', "S|<PRN-VP-.-''>"],
#   ['NP', 'S|<IN-VP>'],
#   ['NP', 'S|<PP-VP-.>'],
#   ['S+VP', "S|<,-NP-VP-.-''>"],
#   ['ADVP', 'S|<NP-,-NP-VP-.>'],
#   ['``', 'S|<S-,-CC-S-.>'],
#   ['``', "S|<PP-,-NP-VP-.-''>"],
#   ['ADVP', 'S|<S-CC-S>'],
#   ['SBAR', 'S|<NP-VP>'],
#   ['``', "S|<S-,-''-PRN-,-``-CC-S-.>"],
#   ['PP', 'S|<PP-,-NP-VP-.>'],
#   ['PP', 'S|<PP-NP-,-NP-VP-.>'],
#   ['CC', 'S|<S-,-CC-S-.>'],
#   ['PRN', 'S|<NP-VP>'],
#   ['CC', "S|<PRN-``-NP-VP-,-''>"],
#   ['CC', "S|<NP-VP-.-''>"],
#   ['``', 'S|<PP-,-NP-VP-.>'],
#   ['``', 'PP'],
#   ['``', 'S|<S-,-NP-VP-.>'],
#   ['-LRB-', 'S|<NP-VP-.--RRB->'],
#   ['S', 'S|<PRN-CC-S-.>'],
#   ['S', 'S|<PRN-``-CC-S-.>'],
#   ['S+VP', 'S|<NP-VP-.>'],
#   ["''", 'S|<NP-VP-.>'],
#   ['NP', 'S|<RB-VP-.>'],
#   ['``', "S|<NP-PRN-``-VP-.-''>"],
#   ['CC', 'S|<NP-VP>'],
#   ['``', "S|<S-PRN-``-CC-S-.-''>"],
#   ['``', 'S|<SBAR-VP-.>'],
#   ['S', 'S|<,-PRN-``-S-.>'],
#   ['S', 'S|<:-S-:-S>'],
#   ['LST', 'S|<INTJ-,-NP-VP-PRN>'],
#   ['LST', 'S|<S-CC-S-PRN>'],
#   ['INTJ', 'S|<,-NP-VP>'],
#   ['LST', 'S|<NP-VP-PRN>'],
#   ['``', 'S|<S-PRN-``-CC-S-.>'],
#   ['S', "S|<:-CC-S-.-''>"],
#   ['``', "S|<S-,-''-PRN-,-``-CC-S-.-''>"],
#   ['SBAR', 'S|<,-NP-ADVP-VP>'],
#   ['NP', 'S|<VP-CC-VP>'],
#   ['S', "S|<CC-S-.-''>"],
#   ['S', 'S|<:-S-,-CC-S-.>'],
#   ['CC', "S|<PP-PRN-``-NP-VP-.-''>"],
#   ['``', "S|<S-,-''-PRN-``-CC-S-.>"],
#   ['``', "S|<S-,-NP-VP-.-''>"],
#   ['NP', 'S|<DT-VP-.>'],
#   ['CC', 'S|<PP-,-NP-VP>'],
#   ['``', 'S|<S-,-CC-S>'],
#   ['SBAR', 'S|<NP-ADVP-VP-.>'],
#   ['SBAR', 'S|<:-ADVP-,-NP-VP-.>'],
#   ['NP', "S|<NP-VP-.-''>"],
#   ['PP', 'S|<,-PP-NP-VP-.>'],
#   ['CC', 'S|<PP-,-NP-ADVP-VP-.>'],
#   ['S', 'S|<IN-S>'],
#   ['NP', 'S|<VP-PP>'],
#   ['S', "S|<,-S-.-''>"],
#   ['S', 'S|<:-JJ-,-S>'],
#   ['S+VP', 'S|<,-NP-VP>'],
#   ['NP', 'S|<,-NP-VP>'],
#   ['``', "S|<IN-NP-VP-.-''>"],
#   ['S+VP', 'ADJP'],
#   ['NP', 'S|<PRN-NP-NP-VP-.>'],
#   ['S+VP', 'S|<:-NN-S>'],
#   ['NP', 'S|<PRN-ADVP-VP-.>'],
#   ['VP', "S|<NP-:-``-S-.-''>"],
#   ['LST', 'S|<VP-.>'],
#   ['CC', 'S|<PP-NP-VP-.>'],
#   ['NP', 'UCP'],
#   ['S+VP', 'S|<:-S-.>'],
#   ['RB', 'S|<VP-.>'],
#   ['ADVP', 'S|<NP-NP-VP-.>'],
#   ['CC', 'S|<SBAR-,-NP-VP-.>'],
#   ['RB', 'VP'],
#   ['S', 'S|<,-NP-VP-,>'],
#   [':', 'S|<S-:-S-.>'],
#   ['``', "S|<S-,-CC-S-,-CC-S-.-''>"],
#   ['VP', ','],
#   ['RB', 'S|<,-PP-,-NP-VP-.>'],
#   ['NP', 'S|<ADVP-PP>'],
#   ['NP', "S|<``-NP-''>"],
#   ['``', "S|<SINV-,-''-NP-VP-.>"],
#   ['PP', 'S|<,-NP-ADVP-VP>'],
#   ['S', 'S|<,-NP-VP>'],
#   ['PP', 'S|<,-``-NP-VP>'],
#   ['S', 'S|<,-S-.>'],
#   ['CC', 'VP'],
#   ['``', "S|<CC-NP-VP-.-''>"],
#   ['PP', 'S|<,-``-NP-VP-.>'],
#   ['S', 'S|<NP-VP-.>'],
#   ['CC', 'S|<PP-PRN-NP-VP-.>'],
#   ['RB', 'S|<,-SBAR-,-NP-VP-.>'],
#   ['PP', 'S|<:-NP-VP-.>'],
#   ['SBAR', 'S|<,-``-NP-VP-.>'],
#   ['NP', 'S|<ADJP-NP>'],
#   ['ADJP', 'SBAR'],
#   ['ADVP', 'S|<,-SBAR-,-NP-VP-.>'],
#   ['ADVP', 'S|<,-PP-,-NP-ADVP-VP-.>'],
#   ['S', 'S|<,-CC-S-,-CC-S-.>'],
#   ['PP', "S|<,-''-NP-VP-.>"],
#   ['NP', 'S|<VP-:-``-S>'],
#   ['S', 'S|<,-S-CC-S-.>'],
#   ['ADVP', "S|<,-NP-VP-.-''>"],
#   ['NP+NP', 'S|<VP-:-FRAG-.>'],
#   ['``', 'S|<NP-ADVP-VP-.>'],
#   ['RB', 'S|<NP-VP>'],
#   ['-LRB-', 'S|<NP-NP-VP-.--RRB->'],
#   ['NP', 'S|<ADVP-:-VP>'],
#   ['ADVP', 'S|<,-``-NP-VP>'],
#   ['CC', 'S|<NP-NP-VP>'],
#   ['IN', 'S|<NP-VP-.>'],
#   ['CC', "S|<``-SBAR-,-NP-VP-.-''>"],
#   ['SBAR', 'S|<,-NP-PP-VP>'],
#   ['ADVP', 'ADJP'],
#   ['SBAR', 'S|<,-PP-,-NP-VP-.>'],
#   ['PP', 'S|<,-NP-VP-:-S-.>'],
#   ['``', "S|<NP-VP-,-''>"],
#   ['S+VP', 'S|<,-NP-NP-VP-.>'],
#   ['NP', 'S|<VP-,-CC-S-.>'],
#   ['S', 'S|<,-CC-SINV-.>'],
#   ['``', "S|<S-''-NP-VP-.>"],
#   ['ADVP', 'S|<PRN-NP-VP>'],
#   ['NP', 'S|<``-RB-ADJP>'],
#   ['``', "S|<SBAR-,-NP-VP-,-''>"],
#   ['NP', 'S|<CONJP-VP>'],
#   ['S', 'S|<,-S-,-CC-S>'],
#   ['SBAR', 'S|<,-S-VP-.>'],
#   ['S+VP', 'S|<:-``-S-.>'],
#   ['S', "S|<:-S-.-''>"],
#   ['S+VP', 'S|<,-CC-S-.>'],
#   ['NP', 'S|<,-SBAR-,-VP-.>'],
#   ['NP', "S|<,-VP-.-''>"],
#   ['S', 'S|<,-RB-S-.>'],
#   ['CC', 'S|<,-ADVP-,-NP-VP-.>'],
#   ['IN', 'S|<NP-VP>'],
#   [':', 'S|<NP-VP-.>'],
#   [',', 'S|<PP-,-PP-NP-VP>'],
#   [',', 'S|<PP-,-NP-VP>'],
#   [':', 'S|<CC-NP-VP-.>'],
#   [',', 'S|<SBAR-,-NP-VP>'],
#   ['IN', 'S|<ADVP-NP-VP-:>'],
#   ['``', "S|<S-,-''-''-CC-S>"],
#   ['IN', 'S|<NP-PRN-VP-.>'],
#   ['``', 'S|<S-NP-VP-.>'],
#   ['ADVP', "S|<NP-ADVP-VP-.-''>"],
#   ['S', 'S|<,-S-,-S-.>'],
#   ['NP', 'S|<VP-CC-S-.>'],
#   ['NP', 'S|<VP-ADVP>'],
#   ['NP', "S|<VP-:-.-''>"],
#   ['S+VP', 'S|<,-S>'],
#   ['S+VP', 'S|<:-CC-,-ADVP-,-S>'],
#   ['S', "S|<:-``-S-.-''>"],
#   ['ADVP', "S|<NP-VP-.-''>"],
#   ['``', "S|<NP-''>"],
#   ['SBAR', 'S|<PRN-,-NP-VP-.>'],
#   ['``', "S|<ADVP-,-S-,-CC-S-.-''>"],
#   ['ADVP', 'S|<,-NP-ADVP-VP>'],
#   ['``', "S|<FRAG-''-VP-.>"],
#   ['SBAR', 'S|<,-VP-.>'],
#   ['PP', 'S|<,-ADVP-,-NP-VP>'],
#   ['NP', 'S|<``-NP>'],
#   ['``', 'S|<PP-NP-VP>'],
#   ['NP', 'S|<VP-:-NP-.>'],
#   ['ADJP', 'NP'],
#   ['SBAR', 'S|<,-ADVP-NP-VP-.>'],
#   ['CC', 'S|<NP-PRN-ADVP-VP-.>'],
#   ['NP', 'S|<ADJP-PP>'],
#   ['S', "S|<,-''-PRN-,-CC-S-.-''>"],
#   ['``', 'S|<SBAR-,-NP-VP>'],
#   ['S', "S|<''-VP-.>"],
#   ['INTJ', 'S|<,-NP-VP-,>'],
#   ['PP', 'S|<,-S-,-CC-S-.>'],
#   ['``', 'S|<VP-.>'],
#   ['NP', "S|<VP-.-''-''>"],
#   ['S', "S|<,-CC-S-,-CC-S-.-''>"],
#   ['NP+NP', 'S|<ADJP-S>'],
#   ['SBAR', 'S|<NP-VP-.>'],
#   ['-LRB-', 'S|<S-,-CC-S-.--RRB->'],
#   ['S+VP', 'S|<CC-S-.>'],
#   ['S', 'S|<,-S>'],
#   ['NP', 'S|<INTJ-VP>'],
#   ['S+VP', 'S|<VP-.>'],
#   ['SBAR', 'S|<,-S-,-CC-S>'],
#   ['CC', 'S|<NP-,-SBAR-,-VP>'],
#   ['ADVP', 'NP'],
#   ['S', "S|<PRN-``-CC-S-.-''>"],
#   ['CC', 'S|<PP-,-S-,-CC-S-.>'],
#   ['CC', "S|<,-SBAR-:-``-NP-VP-.-''>"],
#   ['NP', 'S|<``-VP-.>'],
#   ['ADVP', 'PP'],
#   ['CC', "S|<``-S-,-''-NP-VP-.>"],
#   ['``', "S|<S-,-''-''-NP-VP-.>"],
#   ['``', 'S|<SBAR-,-NP-VP-.>'],
#   ['PP', 'S|<,-SBAR-,-NP-ADVP-VP-.>'],
#   ['CC', 'S|<``-NP-VP>'],
#   ['CC', 'S|<SBAR-,-NP-NP-VP-.>'],
#   [',', 'S|<PP-,-VP>'],
#   ['NP', 'S|<``-ADVP-ADVP-VP>'],
#   ['NP', 'S|<,-ADVP-,-VP>'],
#   ['``', 'S|<CC-PP-,-NP-VP-.>'],
#   ['ADVP', 'S|<ADVP-,-NP-VP-.>'],
#   ['CC', 'S|<SBAR-,-PP-NP-VP-.>'],
#   ['SBAR', "S|<,-PP-,-SBAR-``-NP-VP-.-''>"],
#   ['S', 'S|<,-S-CC-S>'],
#   ['NP', 'S|<ADJP-ADVP>'],
#   ['FRAG', 'S|<,-NP-VP-.>'],
#   ['NP+NP', 'PP=3'],
#   ['CC', 'S|<SBAR-,-NP-VP>'],
#   ['NP', 'S|<NP-ADVP-VP>'],
#   ['PP', 'S|<,-S-CC-S-.>'],
#   ['``', "S|<FRAG-,-''-NP-VP-.>"],
#   ['NP', 'S|<PP-,-ADVP-ADVP=3>'],
#   ['LST', 'S|<PP-,-NP-VP-.>'],
#   ['TO', 'VP'],
#   ['PRN', 'S|<NP-ADVP-VP>'],
#   ['ADVP', 'S|<NP-ADVP-VP>'],
#   ['NP', 'S|<,-SBAR-,-ADVP-VP-.>'],
#   ['ADVP', 'S|<PRN-SBAR-,-NP-VP-.>'],
#   ['PP', 'S|<,-S-,-NP-ADVP-VP-.>'],
#   ['NP', 'S|<,-SBAR-,-VP>'],
#   ['NP', 'S|<VP-SBAR>'],
#   ['ADVP', 'S|<,-S-,-CC-S>'],
#   ['ADVP', "S|<PRN-``-NP-VP-.-''>"],
#   ['PP', 'S|<,-NP-,-S-,-VP-.>'],
#   ['``', "S|<NP-VP-.-''-''>"],
#   ['-LRB-', 'S|<NP--RRB--ADVP>'],
#   ['S', 'S|<,-S-CC-S-,-SBAR-.>'],
#   ['NP', 'VP=2'],
#   ['NP', "S|<,-S-,-VP-.-''>"],
#   ['NP', 'S|<,-S-,-ADVP-VP-.>'],
#   ['PP', 'PP'],
#   ['ADVP', 'S|<,-NP-PP-VP-.>'],
#   ['NP+NP', 'S|<ADJP-SBAR>'],
#   ['ADVP', 'S|<,-NP-ADVP-VP-.>'],
#   ['CC', 'S|<SBAR-NP-VP-.>'],
#   ['CC', 'S|<NP-PP-VP-.>'],
#   ['S', 'S|<,-NP-ADVP-VP-.>'],
#   ['CC', 'S|<``-NP-VP-.>'],
#   ['S+ADJP', 'S|<,-NP-VP>'],
#   ['NP', 'S|<,-NP-,-VP-.>'],
#   ['NP+NP', 'S|<NP-PP-VP>'],
#   ['PP', 'S|<NP-NP-VP-.>'],
#   ['PP', 'S|<,-NP-NP-VP>'],
#   ['S', 'S|<,-CC-``-S-.>']],
#  'NP': [['NP', 'NP|<,-ADJP-,>'],
#   ['NNP', 'NNP'],
#   ['CD', 'NNS'],
#   ['DT', 'NN'],
#   ['DT', 'NP|<JJ-NN>'],
#   ['NNP', 'CD'],
#   ['NP', 'PP'],
#   'NN',
#   ['NP', 'NP|<,-NP>'],
#   ['DT', 'NP|<NNP-VBG-NN>'],
#   ['NP', 'NP|<,-UCP-,>'],
#   ['JJ', 'NN'],
#   ['NNP', 'NP|<NNP-NNP-NNP>'],
#   ['DT', 'NP|<JJ-JJ-NN>'],
#   ['NP', 'RRC'],
#   ['NNP', 'NP|<NN-NNS>'],
#   ['NP', 'NP|<PP-PP>'],
#   ['NN', 'NNS'],
#   ['NP', 'RRC+VP'],
#   'NNS',
#   'PRP',
#   ['QP', 'NNS'],
#   ['NP', 'NP|<,-NP-,>'],
#   ['DT', 'NP|<NN-NN>'],
#   ['DT', 'NNS'],
#   ['RB', 'NP|<JJ-NNS>'],
#   ['NP', 'SBAR'],
#   ['NP', 'NP|<PP-SBAR>'],
#   ['ADJP', 'NP|<NNP-NNP>'],
#   ['NNP', 'NNS'],
#   ['PRP$', 'NP|<NN-NN-NNS>'],
#   'CD',
#   ['JJ', 'NNS'],
#   ['QP', 'NN'],
#   ['DT', 'NP|<JJS-NNS>'],
#   ['NP', 'NP|<NNP-NNP-NNP>'],
#   ['NN', 'POS'],
#   'NNP',
#   ['NP', 'ADJP'],
#   ['DT', 'NP|<NNP-NN>'],
#   'DT',
#   ['DT', 'NP|<JJ-NNS>'],
#   'EX',
#   ['PRP$', 'NNS'],
#   ['DT', 'NP|<NP-CC-NP>'],
#   ['DT', 'NP|<NNP-NNS>'],
#   ['NNP', 'NP|<NNP-NNP>'],
#   ['NNP', 'POS'],
#   ['NP', 'NP|<CC-NP>'],
#   ['DT', 'NP|<NNP-NNP-NNP>'],
#   ['ADJP', 'NNS'],
#   ['DT', 'NP|<JJ-CD>'],
#   ['QP', 'NP|<NNP-NNS>'],
#   ['QP', 'NP|<DT-VBN-NN>'],
#   ['DT', 'NP|<CD-VBG-NNS>'],
#   ['ADJP', 'NN'],
#   ['NP', 'NP|<,-NP-CC-NP>'],
#   ['NN', 'NN'],
#   ['NN', 'NP|<NN-NNS>'],
#   ['DT', 'NP|<NAC-NN-NN>'],
#   ['DT', 'JJS'],
#   ['DT', 'NP|<NN-NNS>'],
#   ['JJ', 'NP|<VBN-NNS>'],
#   ['NP', 'NP|<,-SBAR-,>'],
#   ['NNP', 'NP|<CC-NNP-NNP>'],
#   ['NP', 'NP|<PP-S>'],
#   ['DT', 'NNP'],
#   ['NP', 'VP'],
#   ['NP', 'NP|<PP-,-NP-,>'],
#   ['JJS', 'NNS'],
#   ['DT', 'NP|<JJ-VBN-NNS>'],
#   ['DT', 'NP|<JJR-NN>'],
#   ['DT', 'NP|<JJ-,-JJ-NNS>'],
#   ['DT', 'NP|<NAC-NNP>'],
#   ['RBR', 'NP|<JJ-NN-NNS>'],
#   ['ADJP', 'NP|<VBG-NNS>'],
#   ['DT', 'CD'],
#   ['JJ', 'NP|<NN-NNS>'],
#   ['DT', 'NP|<VBN-NN>'],
#   ['NN', 'NP|<CC-NN-NNS>'],
#   ['``', "NP|<NP-PP-''-SBAR>"],
#   ['DT', 'NP|<NNS-CC-NNS>'],
#   ['NNP', 'NP|<CC-NNP>'],
#   ['NP', 'NP'],
#   ['PRP$', 'NP|<NN-NN>'],
#   ['JJ', 'NP|<JJ-NNS>'],
#   ['NNS', 'SBAR'],
#   ['DT', 'NP|<JJ-JJ-NN-NN>'],
#   ['DT', 'NP|<CD-JJ-NNS>'],
#   ['CD', 'NN'],
#   ['NP', 'NNS'],
#   ['DT', 'NP|<NNS-POS>'],
#   ['JJ', 'NNP'],
#   ['JJR', 'NNS'],
#   ['VBG', 'NP|<NN-NNS>'],
#   ['RB', 'NP|<JJR-NNS>'],
#   ['VBG', 'NNS'],
#   ['NP', 'NP|<PP-,-RRC-,>'],
#   ['NP', 'PRN'],
#   ['JJ', 'NP|<NNP-NNS>'],
#   ['NP', 'NN'],
#   ['DT', 'NP|<JJS-NN>'],
#   ['DT', 'NP|<JJ-NN-NNS>'],
#   ['DT', 'NP|<JJ-NN-NN>'],
#   ['PRP$', 'NN'],
#   ['DT', 'NP|<JJ-JJ-JJ-NN>'],
#   ['DT', 'NP|<CD-NNS>'],
#   ['DT', 'NP|<JJ-CD-NN>'],
#   ['NP', 'NP|<,-SBAR>'],
#   ['NNP', 'NP|<NNP-CC-NNP>'],
#   ['DT', 'NP|<ADJP-NN>'],
#   ['NP', 'NP|<,-NP-,-SBAR>'],
#   ['ADVP', 'NP|<DT-NNP-NNP-NN-NN>'],
#   ['NP', 'NP|<CD-NN-NNS>'],
#   ['NNP', 'NP|<NNP-POS>'],
#   ['NP', 'NP|<,-CC-NP>'],
#   ['$', 'CD'],
#   ['DT', 'NP|<NN-VBG-NN>'],
#   ['PRP$', 'NP|<NNP-CC-NNP-NN>'],
#   ['NP', 'NP|<PP-PP-PP>'],
#   ['PRP$', 'NP|<NNP-NNP-NNP>'],
#   ['NNP', 'NP|<NNP-.-NNP>'],
#   ['DT', 'NP|<JJ-JJ-VBG-NN>'],
#   ['NP', 'NP|<,-VP-,>'],
#   ['JJ', 'NP|<JJ-NNS-NNS>'],
#   ['NNP', 'NP|<NNS-NNS>'],
#   ['DT', 'NP|<NN-S>'],
#   ['NP', 'NP|<NN-NN>'],
#   ['DT', 'NP|<NN-POS>'],
#   ['NP', 'SBAR+S+VP'],
#   'RB',
#   ['DT', 'NP|<NNP-NNS-CC-NN-NN>'],
#   ['JJ', 'NP|<NN-NN-NNP-NNP-NNP>'],
#   ['NP', 'NP|<NNP-NNS-,-NN-,-NNS-CC-NN-NNS>'],
#   ['JJ', 'NP|<NN-NN>'],
#   ['NP', 'NP|<NNP-NN>'],
#   ['DT', 'NP|<NNS-CC-NN-NN>'],
#   ['PRP$', 'NP|<JJ-NN>'],
#   ['NP', 'NP|<VBG-NNS>'],
#   ['DT', 'NP|<NNP-NNP>'],
#   ['PRP$', 'NP|<NN-NN-NN>'],
#   ['CD', 'NP|<JJ-NN-NNS>'],
#   ['DT', 'NP|<VBG-NN>'],
#   ['NP', 'NP|<,-CONJP-NP>'],
#   ['DT', 'NP|<NNP-NNP-NNP-NNP>'],
#   ['NNP', 'NP|<NNP-NNP-NNP-NNP>'],
#   ['DT', 'NP|<NN-NN-NNP-NNP>'],
#   ['NN', 'NP|<CC-NN>'],
#   ['NN', 'NP|<CC-NNS>'],
#   ['RB', 'NP|<DT-JJ-NNP-CD-NN>'],
#   ['NNP', 'NP|<CD-NNS>'],
#   ['NP', 'NP|<:-ADVP>'],
#   ['DT', 'NP|<VBN-NNP-NNP-NN>'],
#   ['NP', 'NP|<,-NP-,-NP-CC-NP>'],
#   ['NNP', 'NP|<NN-NN>'],
#   'JJR',
#   ['NP', 'NP|<JJ-NN>'],
#   ['DT', 'NP|<NNP-CC-NNP-NNP>'],
#   ['NP+QP', 'NP|<,-NP-,>'],
#   ['DT', 'NP|<NN-JJR>'],
#   ['NP+QP', 'NP|<,-ADVP>'],
#   ['VBN', 'NP|<NN-NNS>'],
#   ['NP', 'NP|<VBN-NNS>'],
#   ['DT', 'NP|<JJ-NN-JJ-NN>'],
#   'JJ',
#   ['NNP', 'NN'],
#   ['NP', 'SBAR+S'],
#   ['NP', 'NP|<,-NP-,-CC-NP>'],
#   ['NNP', 'NP|<NNP-NNP-POS>'],
#   ['NP', 'NP|<NNP-NNP-CC-NNP-NNP>'],
#   ['NP', 'NP|<,-RRC-,>'],
#   ['NP', 'NP|<NN-NNS>'],
#   ['DT', 'NP|<JJ-,-JJ-NN>'],
#   ['PRP$', 'NP|<VBN-NN-NN-NN>'],
#   ['DT', 'NP|<JJR-NN-NN>'],
#   ['PRP$', 'NP|<CD-NN-NNS>'],
#   ['PRP$', 'NP|<CD-NN>'],
#   ['DT', 'NP|<JJ-CD-NNS>'],
#   ['NP', 'NP|<PP-,-PP>'],
#   ['NNS', 'NP|<CC-NNS>'],
#   ['DT', 'NP|<JJS-RB>'],
#   ['DT', 'NP|<VBG-JJ-NNS>'],
#   ['NN', 'NP|<CD-NN-NNS>'],
#   ['DT', 'QP'],
#   ['PRP$', 'NP|<JJ-NN-NN>'],
#   ['NP+NP', 'NP|<CC-NP-PP>'],
#   ['NP', 'NP|<VP-PRN>'],
#   'WDT',
#   ['RB', 'NP|<DT-CD>'],
#   ['NP', "NP|<''-SBAR>"],
#   ['NP', 'NP|<NN-S>'],
#   ['DT', 'NP|<JJ-NN-POS>'],
#   ['DT', 'NP|<NN-SBAR>'],
#   ['JJR', 'NP|<NN-NNS>'],
#   ['DT', 'NP|<JJ-CD-JJ-NNS>'],
#   ['NP', 'NP|<PP-VP>'],
#   ['NAC', 'NNS'],
#   ['NP', 'NP|<,-PP-,>'],
#   ['NNP', 'NP|<NNP-NNP-NNP-JJ-NN>'],
#   ['NP', 'NP|<,-CC-NP-,>'],
#   ['NP', 'NP|<,-UCP>'],
#   ['JJ', 'NX'],
#   ['NNPS', "NP|<``-NNP-''-NNP-NNP>"],
#   ['NP', 'NP|<,-NP-,-NP>'],
#   ['DT', 'NP|<NN-NNS-CC-NNS-NN-NN>'],
#   ['VBN', 'NP|<NNP-NNP-JJ-NN-NN>'],
#   ['NNP', 'NP|<NNP-NN>'],
#   ['PRP$', 'NP|<JJ-CC-JJ-NNS>'],
#   ['DT', 'NP|<UCP-NN>'],
#   ['NN', 'NP|<NN-NNP-NNP-NNP>'],
#   ['NP+QP', 'ADVP'],
#   ['NP', 'NP|<SBAR-,-PP>'],
#   ['JJ', 'NP|<NNS-S>'],
#   ['DT', 'NP|<VBG-NN-NN>'],
#   ['PRP$', 'NP|<CD-NNS>'],
#   ['NP+QP', 'NP|<,-CC-NP>'],
#   ['DT', 'NP|<NNP-NNP-NN>'],
#   ['DT', 'NP|<QP-NNS>'],
#   ['DT', 'NP|<JJ-QP-NNS>'],
#   ['DT', 'NP|<ADJP-NNP-CD-NN>'],
#   ['DT', 'NP|<VBN-CD-NN>'],
#   ['PRP$', 'NP|<NN-NNS>'],
#   ['PRP$', 'NP|<QP-NNS>'],
#   ['NP+QP', 'PP'],
#   ['DT', 'NP|<JJ-QP>'],
#   ['PRP$', 'NP|<JJ-NN-JJ-NNS>'],
#   ['NP', 'NP|<NNP-CD-NN>'],
#   ['NP+QP', 'NP|<PP-SBAR>'],
#   ['DT', 'NP|<NNP-CD-NN>'],
#   ['PRP$', 'NP|<NNP-NNP-JJ-NN>'],
#   ['NP', 'NP|<JJ-NNS>'],
#   ['NNS', 'NP|<,-NNS-CC-NNS>'],
#   ['NP', 'NNP'],
#   ['DT', 'NP|<NNP-NNP-NNPS-POS>'],
#   ['NP', 'NP|<PP-,-SBAR-,>'],
#   ['NNP', 'NP|<NNPS-NNP-NNP>'],
#   ['NNP', 'NP|<NNPS-NNP>'],
#   ['NN', 'NP|<NNP-NNP-NNP>'],
#   ['DT', 'NP|<NN-PRN>'],
#   ['PRP$', 'NX'],
#   ['NP', 'NP|<VP-PP>'],
#   ['DT', 'NP|<NNPS-CC-NNP-NNP>'],
#   ['DT', 'NP|<JJ-NNP-NNP>'],
#   ['JJ', 'NP|<NNP-NNP>'],
#   ['NP', 'NP|<NN-JJ-NN>'],
#   ['ADVP', 'NP|<DT-QP>'],
#   'IN',
#   ['``', "NP|<DT-JJ-''-NN>"],
#   ['PRP$', 'NP|<ADJP-JJ-NN>'],
#   ['NP', 'NP|<JJ-,-JJ-NN-NN>'],
#   ['DT', 'NP|<NNP-POS>'],
#   ['JJ', 'NP|<JJ-NN-NN>'],
#   ['DT', 'NP|<JJS-JJ-NN>'],
#   ['NP', 'NP|<,-PP>'],
#   ['NNP', 'NP|<NNP-NNPS-NNP>'],
#   ['NP', 'NP|<:-NP>'],
#   ['NP', 'NP|<JJ-CD>'],
#   ['QP', 'NP|<JJ-NNS>'],
#   ['RB', 'NP|<DT-NNP-NN-NN>'],
#   ['NNP', 'NP|<NNP-NNS>'],
#   ['CD', 'NP|<NNP-NNP-NN>'],
#   ['QP', 'NP|<NNP-NNP-NNS>'],
#   ['NP', 'NP|<JJ-NN-NN>'],
#   ['NP+QP', 'NP'],
#   ['ADVP', 'DT'],
#   ['DT', 'NP|<CD-NN>'],
#   ['DT', 'NP|<NNP-NN-CC-NN-NNS>'],
#   ['DT', 'NP|<JJ-DT>'],
#   ['DT', 'NP|<JJ-NAC-NN>'],
#   ['NP', 'NP|<SBAR-PP>'],
#   ['JJ', 'NP|<JJ-NN>'],
#   ['NP', 'NP|<:-NP-:-NP-:-CC-NP>'],
#   ['NN', 'NP|<NN-NN>'],
#   ['NNP', 'NP|<NN-NNP>'],
#   ['JJ', 'NP|<NN-NN-NN>'],
#   ['NN', 'NP|<VBG-NN>'],
#   ['DT', 'NP|<NN-NN-NN>'],
#   ['NP', 'NP|<NNP-NNP-NNP-NN>'],
#   ['RB', 'NN'],
#   ['NNP', 'NNPS'],
#   ['NNP', 'NX'],
#   ['NP', 'NP|<:-NP-:>'],
#   ['CD', 'NP|<JJ-NNS>'],
#   ['NNP', 'NP|<,-NNP-,-NNP-,-NNP-CC-NNP>'],
#   ['DT', 'NP|<JJ-NN-NN-NN>'],
#   ['DT', 'NP|<JJ-NNP-NN-NN>'],
#   ['NP', "NP|<''-PP>"],
#   ['VBG', 'NN'],
#   ['NP', 'NP|<,-CC-ADVP-NP>'],
#   ['DT', 'NP|<VBG-NNS>'],
#   ['DT', 'NP|<``-NN-CC-NN>'],
#   ['DT', 'NP|<-LRB--VBG--RRB--NN-POS>'],
#   ['PRP$', 'NP|<JJ-NNS-CC-NNS>'],
#   ['PRP$', 'NP|<JJS-NNS>'],
#   ['NP', 'NP|<VBG-NN>'],
#   ['JJ', 'NP|<NN-CC-NN-NNS>'],
#   ['DT', "NP|<``-NN-''-NN>"],
#   ['NP', 'NP|<PP-,-VP-,>'],
#   ['DT', 'NP|<VBG-NN-SBAR>'],
#   ['PRP$', 'NP|<NNS-S>'],
#   ['VBG', 'NP|<JJ-NN>'],
#   ['JJR', 'NP|<NNP-NN-NNS>'],
#   ['NNP', 'NP|<JJ-NNS>'],
#   ['DT', 'NP|<CD-NN-NN>'],
#   ['DT', 'NP|<JJ-JJ-CD-NN>'],
#   ['JJ', 'NP|<DT-NN>'],
#   ['RB', 'RB'],
#   ['NNP', 'NP|<NNP-NNP-NNP-NNP-NNP>'],
#   ['JJ', 'NP|<NN-NNP-NNP>'],
#   ['PDT', 'NP|<DT-NN>'],
#   ['DT', 'NP|<JJ-$-CD>'],
#   ['DT', 'NP|<NN-CC-NN>'],
#   ['JJR', 'NP|<JJ-NNS>'],
#   ['DT', 'NP|<NNP-,-NNP-CC-NNP>'],
#   ['JJ', 'NP|<NN-NN-NNS>'],
#   ['ADVP', 'NP|<NP-PP>'],
#   ['CD', 'NP|<NNP-NNS>'],
#   ['DT', 'NP|<JJ-NNS-NN>'],
#   ['PRP$', 'NP|<NNP-NNP-NN>'],
#   ['DT', 'NP|<ADJP-NNS-NN>'],
#   ['PRP$', 'NP|<JJ-VBN-NN-NNS>'],
#   ['NP', 'NP|<NNP-NNP-NNS>'],
#   ['DT', 'JJ'],
#   ['DT', 'NP|<NNP-CC-NNP-NNS>'],
#   ['NP', 'NP|<PP-PP-NP>'],
#   ['JJR', 'NP|<DT-NN>'],
#   ['PRP$', 'NP|<JJ-NNS>'],
#   ['DT', 'NP|<NNP-NNPS>'],
#   'NNPS',
#   ['NP', 'NP|<PP-,-VP>'],
#   ['CD', 'NP|<JJ-NNP-NN-NNS>'],
#   ['VB', 'NNS'],
#   ['DT', 'NP|<JJ-NNP-NN-CC-NN>'],
#   ['JJ', 'NP|<VBG-NNS>'],
#   ['DT', 'NP|<NNP-NN-NNS>'],
#   ['NP', 'NP|<PP-NP>'],
#   ['NP', 'NP|<JJ-JJ-NN>'],
#   ['ADVP', 'NP|<NN-NN-NN>'],
#   ['JJ', 'NP|<NNS-NN>'],
#   ['NN', 'NP|<CC-VBG-NN>'],
#   ['CD', 'NP|<JJ-NN-JJ-JJ-NNS>'],
#   ['DT', 'NP|<NNP-NNP-NNP-NNP-NNP>'],
#   ['DT', 'NP|<JJ-,-ADJP-JJ-NNS-JJ-NN>'],
#   ['DT', 'NP|<NNP-NNP-NN-NN>'],
#   ['DT', 'NP|<JJS-CD-NNS>'],
#   ['NNP', 'NP|<,-NNP-CC-NNP>'],
#   ['NP', 'NP|<NNP-NNPS-NNP>'],
#   ['DT', 'NP|<NNP-NN-VBD-NN>'],
#   ['JJ', 'NP|<CC-JJ-NNS>'],
#   ['NP', 'NP|<PP-ADJP>'],
#   ['DT', 'NP|<NN-,-NN-CC-NN-NNS-NN>'],
#   ['DT', 'NP|<JJ-NN-S>'],
#   ['NN', 'CD'],
#   ['NNS', 'POS'],
#   ['JJ', 'NP|<NN-NN-NNP-NNP>'],
#   ['PRP$', 'NP|<NNP-NNP-NNP-JJ-NN>'],
#   ['PRP$', 'NP|<ADJP-NN-NN>'],
#   ['NP', 'NP|<ADJP-PP>'],
#   ['DT', 'NP|<DT-JJ-NNS>'],
#   ['DT', 'NNPS'],
#   ['NAC', 'NP|<JJ-NN>'],
#   ['DT', 'NP|<JJR-ADJP-NN>'],
#   ['DT', 'NP|<JJS-NN-NN>'],
#   ['JJ', 'NP|<JJ-NN-NNS>'],
#   ['DT', 'NP|<ADJP-NNS>'],
#   ['QP', 'NP|<DT-NN>'],
#   ['NNP', 'NP|<NNP-NNP-CC-NNP>'],
#   ['DT', 'NP|<NNP-NNP-POS>'],
#   ['JJ', 'NP|<NNP-NNP-NNP>'],
#   ['NNP', 'NP|<JJ-NN>'],
#   ['NP', 'NP|<PRN-SBAR>'],
#   ['DT', "NP|<``-JJ-NN-NN-''>"],
#   ['JJ', 'NP|<JJ-JJ-NNS>'],
#   'RBS',
#   ['DT', "NP|<``-JJ-''-NN>"],
#   ['RB', 'CD'],
#   ['NNP', 'NP|<NNP-,-NNP-NNP-CC-NNP>'],
#   ['DT', 'NP|<DT-NN>'],
#   ['NNS', 'NNS'],
#   ['JJ', 'NP|<CC-NN-NNS>'],
#   ['JJS', 'NP|<NN-NNS>'],
#   ['JJ', 'CD'],
#   ['DT', 'NP|<JJ-ADJP-NN>'],
#   ['CD', 'POS'],
#   ['NP', 'NP|<NNP-NNP>'],
#   ['NNP', 'NP|<NNS-CC-NN-NNS>'],
#   ['DT', 'NP|<JJ-NNPS>'],
#   ['NP', 'ADVP'],
#   ['NP', 'NP|<JJ-JJ-NNP-NN>'],
#   ['DT', 'NX'],
#   ['DT', 'NP|<NNP-NNP-NNP-JJ-NN>'],
#   ['VBN', 'NNS'],
#   ['PRP$', 'NP|<JJS-NN>'],
#   ['RB', 'NP|<DT-JJ>'],
#   ['NP+QP', 'NP|<,-ADJP>'],
#   ['DT', 'NP|<NNP-NNP-NNP-POS>'],
#   ['``', "NP|<NP-''-SBAR>"],
#   ['NP', 'NP|<NN-NNS-NN>'],
#   ['DT', "NP|<``-JJ-NN-''-NN>"],
#   ['NNP', 'NP|<,-NNP-CC-NNP-NNP-NNP>'],
#   ['DT', 'NP|<NNS-SBAR>'],
#   ['DT', 'NP|<NN-NN-NNS-NN>'],
#   ['JJ', 'NP|<,-JJ-NN>'],
#   ['JJ', 'NP|<NN-POS>'],
#   ['NP', 'NP|<NN-NN-NNS>'],
#   ['DT', 'NP|<NN-NNS-POS>'],
#   ['NNS', 'NN'],
#   ['JJ', 'NP|<NN-SBAR>'],
#   ['NN', 'SBAR'],
#   ['QP', 'NP|<NN-NNS>'],
#   'RBR',
#   ['CD', 'NP|<NN-POS>'],
#   ['NP', 'NP|<,-VP>'],
#   ['VBN', 'NN'],
#   ['ADJP', 'NP|<NNP-NNS>'],
#   ['ADJP', 'NP|<NN-NNS>'],
#   ['ADJP', 'NP|<JJ-NNS>'],
#   ['NP', 'NP|<PP-PP-,-ADJP>'],
#   ['NP', 'NP|<JJS-NNS>'],
#   ['NP', "NP|<``-NX-''-PRN>"],
#   ['DT', "NP|<JJ-``-JJ-''-NN>"],
#   ['NP', 'NP|<,-ADJP>'],
#   'JJS',
#   ['DT', 'NP|<JJ-,-JJ-,-JJ-NN>'],
#   ['NP', 'NP|<:-CC-NP>'],
#   ['WP', 'RB'],
#   ['``', "NP|<NP-''-PRN>"],
#   ['PRP', 'NP|<NNP-NNP-,>'],
#   ['DT', 'NP|<``-NN>'],
#   ['NP', "NP|<,-NP-,-''>"],
#   ['NNP', 'NP|<NNP-NN-NNP-NNP>'],
#   ['DT', 'NP|<``-JJ-,-JJ-,-JJ-NN>'],
#   'FW',
#   ['PRP', 'NP|<NNP-NNP-NNP>'],
#   ['``', "NP|<NP-''-PRN-PP>"],
#   ['RB', 'NP|<DT-ADJP-NNS>'],
#   ['PRP$', 'NP|<NNS-POS>'],
#   ['RB', 'NP|<DT-JJ-NN>'],
#   ['DT', 'NP|<JJ-,-JJ-JJ-NN>'],
#   ['NP', 'NP|<NN-NN-NNS-NN>'],
#   ['DT', "NP|<``-NNP-NNP-''>"],
#   ['JJ', 'NP|<NNS-CC-NNS>'],
#   ['DT', 'ADJP'],
#   ['DT', 'NP|<NNP-NNP-NNP-NN-NN>'],
#   ['NNP', 'NP|<NNP-NNP-NNP-POS>'],
#   ['DT', 'NP|<ADJP-NN-NN>'],
#   ['JJ', 'NP|<DT-JJ-NN>'],
#   ['DT', 'NP|<NNP-NNP-NNP-NN-NN-NNP>'],
#   ['DT', 'NP|<NNP-JJ-NN>'],
#   ['DT', 'NP|<NNP-POS-NNP>'],
#   ['DT', 'NP|<NP-NNS-CC-NN>'],
#   ['``', "NP|<NP-,-''-PP>"],
#   ['DT', 'NP|<JJ-NN-NN-NNP>'],
#   ['JJR', 'NN'],
#   ['DT', 'NP|<ADJP-NNP-NN>'],
#   ['DT', 'NP|<JJ-NNP-NNP-NN>'],
#   ['NP', 'NP|<,-ADJP-,-ADVP-PP>'],
#   ['NP', 'NP|<PP-NP-PRN>'],
#   ['NP', 'NP|<PRN-PP-,-ADVP>'],
#   ['CD', 'NP|<NN-NN-NNS>'],
#   ['ADJP', 'NP|<NN-NN>'],
#   ['``', "NP|<NP-,-''-NP>"],
#   ['DT', 'NP|<NNP-IN-NNP>'],
#   ['PRP$', 'NNP'],
#   ['NN', 'NP|<NNP-NNP>'],
#   ['RB', 'NNS'],
#   ['JJ', 'NP|<NN-CC-NN>'],
#   ['DT', 'NP|<NNP-NNP-NNS>'],
#   ['DT', 'PRP'],
#   ['NP', 'NP|<PRN-,-SBAR-,>'],
#   ['PRP$', 'NP|<JJ-NP-NN>'],
#   ['RB', 'NP|<JJ-DT-NN>'],
#   ['DT', 'NP|<JJ-NN-NN-NNP-NNP>'],
#   ['PRP$', 'NP|<``-NX>'],
#   ['NP', 'NP|<PRN-PP>'],
#   ['DT', 'NP|<NNP-NN-POS>'],
#   ['CD', 'NP|<JJ-NN>'],
#   ['RB', 'JJ'],
#   ['PRP$', 'JJS'],
#   ['PRP$', 'NP|<JJ-JJ-NNS>'],
#   ['PRP$', 'NP|<JJ-CD-NN>'],
#   ['DT', 'NP|<NNP-NN-NN>'],
#   ['DT', 'NP|<JJR-CD>'],
#   ['JJS', 'NP|<JJ-NNS>'],
#   ['RB', 'NP|<DT-JJ-NNS>'],
#   ['DT', 'NP|<CD-VBG-JJ-NNS>'],
#   ['NP', 'NP|<PP-,-ADJP-,>'],
#   ['NNP', 'NP|<NNP-NNP-:>'],
#   ['DT', 'NP'],
#   ['JJ', 'NP|<,-JJ-JJ-NN>'],
#   ['NP', "NP|<PRN-``-VP-.-''>"],
#   ['``', "NP|<JJ-NNS-,-''>"],
#   ['NP', 'NP|<NNS-NN>'],
#   ['PRP$', 'JJ'],
#   ['CD', 'NP|<JJ-,-JJ-NNS>'],
#   ['DT', 'NP|<DT-NNS>'],
#   ['NN', 'NP|<:-IN-NN-.>'],
#   ['DT', "NP|<``-NN-''>"],
#   ['NNP', ':'],
#   ['JJ', 'NP|<NNP-NNP-NNP-NNP>'],
#   ['NP', 'NP|<VP-SBAR>'],
#   ['DT', 'NP|<NN-FW-NN>'],
#   ['NP', "NP|<PP-''-SBAR>"],
#   ['DT', 'NP|<``-JJ-NN>'],
#   ['PRP$', 'NP|<NN-S>'],
#   ['NP', 'UCP'],
#   ['PDT', 'NP|<DT-JJ-NN>'],
#   ['NNP', 'NP|<NNP-:>'],
#   ['PRP$', 'NP|<JJ-ADJP-NN>'],
#   ['PRP$', 'NP|<PRN-NN>'],
#   ['PRP$', 'NP|<JJ-NNP-NN>'],
#   ['NP', 'NP|<,-ADVP>'],
#   ['NNP', 'NP|<CD-,-CD>'],
#   ['NP', 'NP|<NN-PP>'],
#   ['QP', 'NP|<DT-NNP-NN-NN>'],
#   ['NP', 'NP|<JJ-JJ-NNS>'],
#   ['NP', 'NP|<``-JJ-NNS>'],
#   ['JJ', 'NP|<NNS-POS>'],
#   ['DT', 'NP|<JJ-NN-CC-NN-NN>'],
#   ['NAC', 'POS'],
#   ['DT', 'NP|<ADJP-JJ-NN>'],
#   ['DT', 'NP|<NNP-NNP-NNP-NN>'],
#   ['JJR', 'NP|<JJ-CC-JJ-NNS>'],
#   ['DT', 'NP|<JJ-CC-JJ-NNS>'],
#   ['CD', 'NP|<ADJP-NNS>'],
#   ['NP', 'NP|<CONJP-NP>'],
#   ['NP', 'NP|<,-NP-,-NP-,-NP-,-NP-CC-NP>'],
#   ['NNP', 'NP|<NNP-NNPS>'],
#   ['NAC', 'NP|<NNP-NNP>'],
#   ['DT', 'NP|<VBG-JJ-NN>'],
#   ['JJS', 'NP|<JJ-JJ-NNS>'],
#   ['ADVP', 'NP|<NP-JJS-NN-NN>'],
#   ['NP', 'NP|<NN-SBAR>'],
#   ['JJ', 'NNPS'],
#   ['JJ', 'NP|<NNP-CD>'],
#   ['DT', 'NP|<NNP-CC-NNP>'],
#   ['RB', 'DT'],
#   ['NP', 'NP|<:-VP>'],
#   ['DT', 'NP|<NNS-CC-VBZ>'],
#   ['NP', 'NP|<PP-,-SBAR>'],
#   ['NP', 'NP|<CD-NNP-NNP-NNP>'],
#   ['NN', 'NP|<NNS-CC-NNS>'],
#   ['NNS', 'S+VP'],
#   ['NNS', 'NP|<,-RB-NNS>'],
#   ['DT', 'NP|<NAC-,-JJ-NN-,>'],
#   ['DT', 'NP|<JJ-NN-QP>'],
#   ['NP', 'NP|<NNP-NNP-CC-NNP-NNPS>'],
#   ['DT', 'NP|<JJ-JJ-NNS-CC-NNS>'],
#   ['JJ', "NP|<,-JJ-``-NNS-''>"],
#   ['IN', 'NP|<JJ-NN-NN>'],
#   ['NP', 'NP|<PP-PP-SBAR>'],
#   ['NP', 'NP|<JJS-CC-JJS>'],
#   ['NP', 'NP|<JJ-CD-NNS>'],
#   ['ADJP', 'NP|<NN-NNP-NNP>'],
#   ['NP', 'NP|<CC-NP-CC-NP>'],
#   ['PRP$', 'NP|<CD-ADJP-NN-NNS>'],
#   ['JJ', 'NP|<,-JJ-NN-NNS>'],
#   ['``', "NP|<NP-''-PP>"],
#   ['DT', 'NP|<NN-CC-NNS>'],
#   ['DT', 'NP|<NN-JJ>'],
#   ['CD', 'NP|<CC-CD>'],
#   ['DT', "NP|<NN-``-NN-NN-''-NN>"],
#   ['DT', "NP|<JJ-``-JJ-NN-''-NN>"],
#   ['DT', 'NP|<NN-NNP>'],
#   ['NP', 'NP|<,-NP-SBAR>'],
#   ['DT', 'NP|<RBS-JJ-NN>'],
#   ['PRP', 'NN'],
#   ['DT', 'NP|<NN-NN-NN-NN>'],
#   ['PRP$', 'NP|<JJ-NN-NNS>'],
#   ['NN', 'NP|<,-NN-,-NN>'],
#   ['NP', 'NP|<JJ-NN-NNS>'],
#   ['CD', 'NP|<NN-JJ-NNS>'],
#   ['NP', 'NP|<PP-ADVP-SBAR>'],
#   ['DT', "NP|<''-NNS>"],
#   ['PRP', 'NP|<NN-NN>'],
#   ['NNP', 'NP|<.-NNP>'],
#   ['NP', 'NP|<,-RB-NP-,>'],
#   ['PDT', 'DT'],
#   ['NP', 'NP|<:-PP-:>'],
#   ['PDT', 'NP|<DT-NNS>'],
#   ['DT', 'NP|<ADJP-NX>'],
#   ['DT', 'NP|<JJ-NN-CD>'],
#   ['RB', 'NP|<DT-NN>'],
#   ['JJ', 'NP|<NNS-,-NN-CC-NNS>'],
#   ['DT', 'NP|<VBG-VBG-NN>'],
#   ['NP', 'S+VP'],
#   ['PRP$', 'NP|<NNS-CC-NNS>'],
#   ['DT', 'NP|<NAC-NN>'],
#   ['NP', 'NP|<:-NP-:-CC-NP>'],
#   ['NP', 'NX'],
#   ['NP', 'NP|<,-NP-,-NP-,-NP-,-NP-,-NP-,-NP-CC-NP>'],
#   ['PRP$', 'NP|<NX-JJ-NNS>'],
#   ['NX', 'NP|<NNS-POS>'],
#   ['DT', 'NP|<JJS-NN-NNS>'],
#   ['NP', 'NP|<PP-PRN>'],
#   ['NP', 'NP|<,-NP-,-CC-NP-,>'],
#   ['ADVP', 'NP|<DT-JJ-NN>'],
#   ['NP', 'NP|<CC-ADVP-NP>'],
#   ['NNPS', 'NP|<NNP-CC-NNP>'],
#   ['DT', "NP|<``-JJ-NN-''>"],
#   ['NNP', 'NP|<NNPS-CC-NNP-NNP>'],
#   ['DT', 'NP|<NNP-CC-NNP-NNP-NNP-NNP>'],
#   ['CD', 'NP|<NN-NNS>'],
#   ['JJ', 'NP|<JJ-NNP>'],
#   ['DT', 'NP|<NN-CC-JJ-NNS-NN>'],
#   ['ADJP', 'NP|<JJ-NN>'],
#   ['NNPS', 'POS'],
#   ['RB', 'NP|<JJ-NN>'],
#   ['NP', 'NP|<NNS-S>'],
#   ['``', "NP|<NP-,-''-RB-NP>"],
#   ['DT', 'NP|<JJ-JJ-NNS>'],
#   ['VBN', 'NP|<NN-SBAR>'],
#   ['CD', 'NP|<NNP-NNP-NNS>'],
#   ['JJR', 'NP|<JJ-NN>'],
#   ['CD', 'CD'],
#   ['NP', 'NP|<PP-ADVP>'],
#   ['DT', 'NP|<JJS-JJ-NNS>'],
#   ['DT', 'NP|<CD-JJS-NNP-JJ-NNS>'],
#   ['DT', 'NP|<JJR-NNP-NN-NN>'],
#   ['NNP', 'NP|<CC-NNP-NNS>'],
#   ['NP', 'NP|<,-NP-SBAR-,>'],
#   'VB',
#   ['NNPS', 'NNP'],
#   ['DT', 'NP|<ADJP-NN-VBG-NN>'],
#   ['NNP', 'NP|<NNP-NNPS-CC-NNP>'],
#   ['PRP$', 'NP|<JJ-NN-VBG-NN>'],
#   ['NP', 'NNPS'],
#   ['NNP', 'NP|<NNP-JJ-NN>'],
#   ['PRP$', 'NP|<NN-NNS-NN>'],
#   ['NP', 'NP|<PP-,-``-PP>'],
#   ['CD', 'NP|<NP-NNS>'],
#   ['NP', 'NP|<,-NP-CC-NP-,>'],
#   ['DT', 'NP|<NAC-JJ-NNS-NN>'],
#   ['PRP$', 'NP|<JJ-JJ-NN>'],
#   ['QP', 'NP|<NN-NN-NNS>'],
#   ['NN', 'S+VP'],
#   ['DT', 'NP|<JJ-NNP-NNS>'],
#   ['NP', 'NP|<PP-,>'],
#   ['NP', 'NP|<NNS-SBAR>'],
#   ['JJ', 'NP|<NNP-NNP-NN-NNP>'],
#   ['NP', 'NP|<:-NP-.>'],
#   ['DT', 'NP|<NNPS-NNP>'],
#   ['DT', 'NP|<``-NN-S>'],
#   ['DT', 'NP|<NNPS-NNP-NN>'],
#   ['DT', 'NP|<NN-JJ-NN>'],
#   ['DT', 'NP|<NN-CC-NN-NN>'],
#   ['DT', 'NP|<JJR-NN-NN-SBAR>'],
#   ['JJ', 'NP|<NN-NNP-NNS>'],
#   ['NN', 'NP|<NN-CC-NNS>'],
#   ['NN', 'NP|<NNP-NNS>'],
#   ['DT', 'NP|<JJ-JJS-NN>'],
#   ['DT', 'NP|<NAC-NN-NN-NN>'],
#   ['PRP$', 'NP|<NNP-NNP-NNP-NNP-NNP>'],
#   ['DT', 'NP|<JJ-CD-NNP-NNS>'],
#   ['RBR', 'NP|<DT-NN>'],
#   ['NAC', 'NN'],
#   ['DT', 'NP|<NNS-NN>'],
#   ['NNP', 'NP|<NNP-SYM-NNP-NNP>'],
#   ['NN', 'NP|<,-NN-CC-NN-NN>'],
#   ['PRP$', 'NP|<NN-POS>'],
#   ['NN', 'NP|<NN-NNP-NNP>'],
#   ['QP', 'NP|<NNP-NN>'],
#   ['CD', 'NP|<JJ-JJ-NNS>'],
#   ['NP', 'NP|<NN-CD-NN-NN>'],
#   ['PRP$', 'NP|<JJS-JJ-NNS>'],
#   ['NP', 'NP|<ADJP-NN>'],
#   ['NP', "NP|<,-''-NP>"],
#   ['NP', 'NP|<PP-RRC>'],
#   ['JJ', 'NP|<JJ-JJ-NN-NNS>'],
#   ['NNS', ':'],
#   ['JJ', 'NP|<NNP-NNP-NNP-NNP-NNP>'],
#   ['NN', ':'],
#   ['NP', 'NP|<SBAR-.>'],
#   ['LST', 'NP|<NP-VP>'],
#   ['CD', 'NP|<JJ-NNS-CC-NNS>'],
#   ['DT', 'NP|<CD-JJS-JJ-NNS>'],
#   ['LST', 'NP|<JJ-JJ-NN-.>'],
#   ['NP', 'NP|<NP-.>'],
#   ['DT', 'NP|<NN-ADJP-JJ-JJ-NN>'],
#   ['DT', 'NP|<VBN-ADJP-JJ-NN>'],
#   ['DT', 'NP|<NN-PP-PP-NX>'],
#   ['JJR', 'JJ'],
#   ['JJ', 'JJ'],
#   ['PRP$', 'NP|<NAC-NN>'],
#   ['VBN', 'NP|<JJ-NN>'],
#   ['NP', 'NP|<PRN-:>'],
#   ['NNP', 'NP|<NNP-.>'],
#   ['NNP', '.'],
#   ['UCP', 'NN'],
#   ['JJ', 'NP|<NNP-JJ-NNS>'],
#   ['JJ', 'NP|<-LRB--NN--RRB->'],
#   ['JJ', 'NP|<NNP-NNP-NN>'],
#   ['DT', 'NP|<JJ-NNP-NN>'],
#   ['DT', 'NP|<CD-JJ-NN-JJ-NN-NN>'],
#   ['NN', 'VBG'],
#   ['DT', 'NP|<VBG-NNP-NN>'],
#   ['NP', 'NP|<NP-PP>'],
#   ['DT', 'NP|<NNP-NN-NNS-POS>'],
#   ['NP', 'NP|<CD-NN>'],
#   ['RB', 'JJR'],
#   ['``', "NP|<NNP-''-NNS>"],
#   ['DT', 'NP|<CD-NX>'],
#   ['NP', 'NP|<:-S>'],
#   ['JJ', 'NP|<JJ-NNS-S>'],
#   ['``', "NP|<NP-,-''-NP-SBAR>"],
#   'VBG',
#   ['CD', 'NP|<NN-NN>'],
#   ['NP', 'NP|<:-NP-:-NP-:-NP-:-NP-,-CC-NP>'],
#   ['NP', "NP|<,-VP-,-''>"],
#   ['NAC', 'NP|<VBG-NN-NNP-NNP>'],
#   ['JJ', 'NP|<NNP-POS>'],
#   ['RB', 'NP|<CD-NNS>'],
#   ['PRP$', 'NP|<NNP-NNP-NN-NN>'],
#   ['DT', "NP|<NN-``-PP-''-NN>"],
#   ['NP', 'NP|<JJR-NNS>'],
#   ['DT', 'NP|<NNS-S>'],
#   ['DT', 'NP|<NNS-NNS>'],
#   ['NP', 'NP|<NN-CC-NN>'],
#   ['NNP', 'NP|<NNPS-:-.>'],
#   ['NP', 'NP|<PP-:>'],
#   ['RB', 'NP|<NN-NNS>'],
#   ['PRP$', 'NP|<ADJP-NN>'],
#   ['NP', 'NP|<NNP-NNP-NNPS-NN>'],
#   ['NNP', 'NP|<NNP-CC-NNP-POS>'],
#   ['PRP$', 'NP|<NNP-NN-NN>'],
#   ['CD', 'NP|<NNP-:>'],
#   ['PRP$', 'NP|<JJ-JJ-NN-NN>'],
#   ['NNP', 'NP|<NNPS-:>'],
#   ['DT', 'NP|<NNP-NNP-ADJP-NN>'],
#   ['DT', 'NP|<JJR-JJ-NN>'],
#   ['PRP$', 'NP|<RB-VBN-VBG-NN>'],
#   ['$', 'QP'],
#   ['NNP', 'NP|<NNPS-POS>'],
#   ['DT', 'NP|<``-ADJP-NN>'],
#   ['PDT', 'NP|<DT-NN-NNS>'],
#   ['DT', 'NP|<JJR-NNS>'],
#   ['S', 'NP|<CC-NP>'],
#   ['JJ', 'NP|<ADJP-NNS>'],
#   ['DT', 'NP|<NNP-NNP-NN-NNS>'],
#   ['DT', 'NP|<RB-JJ-NN-S>'],
#   ['CD', 'NP|<NNS-QP>'],
#   ['QP', 'NP|<DT-JJ-NN>'],
#   ['DT', 'NP|<NN-NN-CC-NN-NNS>'],
#   ['PRP$', 'NP|<NNPS-NNP-NNP-NNS>'],
#   ['DT', 'NP|<JJ-NNP-JJ-NN>'],
#   ['IN', 'NN'],
#   ['CD', 'NP|<VBN-NNS>'],
#   ['ADJP', 'NP|<NNP-NNPS-NNP>'],
#   ['DT', 'NP|<NN-NNS-NN>'],
#   ['NAC', 'NNP'],
#   ['NP+QP', 'NP|<,-CC-NP-,>'],
#   ['DT', 'NP|<NNP-NNS-CC-JJ-NNS-NN>'],
#   ['NP', 'NP|<ADJP-VP>'],
#   ['PRP$', 'NP|<CD-NNP-CD-NNP>'],
#   ['NNP', 'NP|<NNP-CD-NNP-NNP-NNP>'],
#   ['DT', 'NP|<JJS-VBG-NNS>'],
#   ['NP', 'NP|<:-NP-,-NP-NP-,-NP>'],
#   ['NNP', 'NP|<,-NNP-,-NNP-,-NNP>'],
#   ['VBN', 'NP|<JJ-NNS>'],
#   ['DT', 'NP|<VBG-NNP>'],
#   ['DT', 'NP|<ADJP-CD>'],
#   ['DT', 'NP|<JJ-NNP>'],
#   ['DT', 'NP|<CD-NNP-IN-NNP-NNP-IN-NNP>'],
#   ['DT', 'NP|<CD-NNP>'],
#   ['NP', 'NP|<NNP-IN-NNP-NNP-IN-NNP>'],
#   ['NP', 'NP|<CD-NNP-NNP-NNP-NNP>'],
#   ['DT', 'NP|<NNP-IN-DT-NNP>'],
#   ['NP', 'NP|<:-NP-:-NP>'],
#   ['PRP$', 'NP|<CD-NNP>'],
#   ['DT', 'NP|<ADJP-NNP>'],
#   ['NP', 'NP|<NNP-NNP-NNP-CD>'],
#   ['NP', 'NP|<NNP-NNP-CD>'],
#   ['DT', 'NP|<CD-CC-CD>'],
#   ['NP+QP', 'NP|<NP-QP>'],
#   ['NP+QP', 'NP|<NP-ADVP>'],
#   ['NP', 'NP|<ADVP-PP>'],
#   ['NP', 'NP|<CC-NP-,-CC-NP>'],
#   ['DT', 'NP|<JJ-NNP-NNP-NNP>'],
#   ['DT', 'NP|<NNP-CD-NNP>'],
#   ['ADVP', 'NP|<$-CD>'],
#   ['JJ', 'NP|<JJ-NNPS-CC-NNPS-CC-NNPS>'],
#   ['NNP', 'NP|<DT-NNP>'],
#   ['CD', 'NP|<CD-NNP>'],
#   ['NP', 'NP|<,-NP-,-CONJP-NP-CC-,-PP-,-NP>'],
#   ['CD', 'NP|<NNP-NNP-CC-NNP>'],
#   ['DT', 'NP|<JJ-NN-NNP>'],
#   ['NP', 'NP|<NNP-CD-NNP-CD>'],
#   ['DT', 'RB'],
#   ['DT', 'NP|<JJ-JJ-NNS-NN-NN>'],
#   ['QP', 'NP|<NN-NN>'],
#   ['DT', 'NP|<NNP-CD-NN-NN-NN>'],
#   ['JJ', 'NP|<,-JJ-NNS>'],
#   ['JJ', 'NP|<JJ-NNS-SBAR>'],
#   ['NNP', 'NP|<NNP-CC-NNP-NNP>'],
#   ['PRP$', 'NP|<VBN-NNS-NN>'],
#   ['CD', 'JJ'],
#   ['VBZ', 'S+VP'],
#   ['DT', 'NP|<NNP-NNP-NNP-CD>'],
#   ['DT', 'NP|<NN-NN-S>'],
#   ['NP', 'NP|<JJ-JJ-VBG>'],
#   [':', 'NP|<NP-PP-,-SBAR-.>'],
#   ['JJ', 'VBG'],
#   ['DT', 'NP|<VBG-QP>'],
#   ['NP+NP', 'SBAR+S'],
#   ['NP', 'X+PP'],
#   ['DT', 'NP|<JJ-NN-NNS-POS>'],
#   ['DT', 'NP|<$-CD>'],
#   ['JJ', 'NP|<NN-NNP-NNP-VBG>'],
#   ['PRP$', 'NP|<NNP-NNP-NNP-NNP-NN>'],
#   ['DT', 'NP|<JJ-NNS-,-NNS-CC-NN-NNS-NN>'],
#   ['JJ', 'SBAR'],
#   ['``', 'NP|<NP-SBAR>'],
#   ['NNP', 'NP|<NNP-NNP-NNP-JJ-VBG>'],
#   ['JJ', 'NP|<VBN-NN>'],
#   ['``', "NP|<QP-''-NNS>"],
#   ['NNP', 'NP|<CC-NNP-POS>'],
#   ['DT', 'NP|<NNP-CC-NNP-NN>'],
#   ['DT', 'NP|<CD-NNS-POS>'],
#   ['NNP', 'NP|<NN-NNP-NN>'],
#   ['NP', 'NP|<-LRB--PP--RRB->'],
#   ['DT', 'NP|<NNP-.>'],
#   ['RB', 'NNP'],
#   ['NP', 'NP|<ADJP-JJ-NN>'],
#   ['NN', 'NP|<NNP-POS>'],
#   ['NP+NP', 'NP|<PP-PP>'],
#   ['CD', 'NP|<NNP-NN>'],
#   ['DT', 'NP|<NNP-CC-JJ-NNS>'],
#   ['NNS', 'NP|<CC-NN-NNS>'],
#   ['JJ', 'NP|<NNS-CC-NN>'],
#   ['QP', 'NP|<NNP-CC-NNP-NNP-NNP-NNS>'],
#   ['NP', 'NP|<JJR-NN>'],
#   ['NP', 'NP|<JJS-VBG-NNS>'],
#   ['NAC', 'NP|<NN-NN>'],
#   ['CD', 'NP|<NNP-NN-NNS>'],
#   ['JJ', 'NP|<JJ-NNP-NNS>'],
#   ['JJ', 'NP|<,-ADJP-NNP-NNS>'],
#   ['NP', 'NP|<JJ-NNP-NNP>'],
#   ['DT', 'NP|<NN-NN-POS>'],
#   ['NP', 'NP|<,-RB-NP>'],
#   ['NNS', 'NP|<,-NN-CC-VBG>'],
#   ['DT', "NP|<DT-``-NN-''>"],
#   ['NNP', 'NP|<,-NNP>'],
#   ['DT', 'NP|<JJ-VBG-NNS>'],
#   ['S+VP', 'NP|<,-NP>'],
#   ['PRP$', 'NP|<NNP-NNS>'],
#   ['NP', 'NP|<NN-CC-JJ-NN-NN>'],
#   ['PRP$', 'NP'],
#   ['NP', 'NP|<RB-NP>'],
#   ['NP', 'NP+QP'],
#   ['PRP$', 'NP|<JJ-VBG-NNS>'],
#   ['PRP$', 'NP|<JJ-NNP-NNP-NNP>'],
#   ['NP', 'NP|<,-ADVP-NP-,>'],
#   ['NN', 'NP|<,-NN-CC-NN>'],
#   ['DT', 'NP|<JJ-NN-NNS-NN>'],
#   ['ADJP', 'NP|<-LRB--NNS--RRB->'],
#   ['DT', 'NP|<NN-JJ-NNS>'],
#   ['PRP$', 'NP|<JJ-NN-NN-NN>'],
#   ['DT', 'NP|<JJ-NX>'],
#   ['PRP$', 'NP|<NNP-NN>'],
#   ['NNS', '.'],
#   ['CD', 'NP|<ADJP-JJ-NNS>'],
#   ['RB', 'NP|<DT-QP-NNS>'],
#   ['NP', 'NP|<SBAR-:>'],
#   ['$', 'NP|<CD-QP>'],
#   ['PRP$', 'NP|<$-CD>'],
#   ['DT', 'NP|<JJ-NNS-CC-NN>'],
#   ['DT', 'NP|<JJ-NN-NN-.>'],
#   ['VBG', 'NP|<NNS-.>'],
#   ['VBN', 'NP|<NNS-NNS>'],
#   ['NP', 'NP|<,-NP-,-CONJP-NP>'],
#   ['VBG', 'NX'],
#   ['DT', "NP|<JJ-``-NN-NN-''>"],
#   ['DT', 'NP|<VBN-NNP-NN-NN>'],
#   ['NNP', 'NP|<CC-NNP-NNP-NNS>'],
#   ['DT', 'NP|<NNP-NNP-NNP-NNP-NN>'],
#   ['PRP$', 'NP|<NP-CD-NN-NNS-NN>'],
#   ['CD', 'NP|<RB-.>'],
#   ['CD', 'RB'],
#   ['DT', 'NP|<JJ-VBG>'],
#   ['JJ', 'NP|<NNS-NNS>'],
#   ['DT', 'NP|<NNP-CD-JJ-NNS-NN>'],
#   ['DT', 'NP|<NNP-NN-NN-NN>'],
#   ['NP', 'NP|<PP-PRN-,-SBAR-,>'],
#   ['PRP$', 'NP|<VBG-JJ-,-JJ-NN>'],
#   ['NNP', 'NP|<CD-JJ-NNS-NN>'],
#   ['NNP', 'NP|<NN-NN-NN>'],
#   ['JJ', 'NP|<VBG-NN>'],
#   ['DT', 'NP|<JJ-VBG-NN>'],
#   ['DT', 'NP|<VBG-CD-NNS>'],
#   ['DT', 'NP|<NNP-NN-CC-NNS-NN>'],
#   ['JJ', 'NP|<NN-S>'],
#   ['DT', 'NP|<NNP-NNP-NN-NN-NN>'],
#   ['DT', 'NP|<CD-NN-NNS>'],
#   ['ADVP', 'NP|<NP-PRN-,-NP>'],
#   ['DT', 'NP|<JJ-NNP-NNP-CC-NNP-NNP-NN>'],
#   [':', "NP|<NP-,-``-NP-''>"],
#   ['CD', 'NP|<NNS-CC-NNS>'],
#   ['PRP$', "NP|<JJ-``-NN-''>"],
#   ['DT', 'NP|<NNP-NN-CC-NN-NN>'],
#   ['NP', 'NP|<PP-:-PP-:-SBAR>'],
#   ['DT', 'NP|<VBN-NN-NN>'],
#   ['DT', 'NP|<RBR-JJ-NN>'],
#   ['NP', 'NP|<PRN-VP>'],
#   ['``', "NP|<NP-,-''-PP-:-NP>"],
#   ['DT', 'NP|<NN-,-CC-NN-,>'],
#   ['NP', "NP|<PP-,-VP-,-''-SBAR>"],
#   ['NNP', 'NP|<NNP-NNP-NN>'],
#   ['DT', 'VBG'],
#   ['IN', 'NP|<JJ-NN>'],
#   ['JJ', 'NP|<NN-NNP-NNP-NNP>'],
#   ['NP', 'NP|<JJS-NN-NNS>'],
#   ['NN', 'NP|<NN-CC-NN>'],
#   ['DT', 'NP|<CD-VBN-NNS>'],
#   ['CD', 'NP|<JJ-NN-QP>'],
#   ['NP', 'NP|<,-NP-,-VP-,>'],
#   ['NP', 'NP|<ADJP-NNS>'],
#   ['NNP', 'NP|<NNP-NNP-NNP-CC-NNP-NNP>'],
#   ['DT', 'NP|<NNP-CD-NNS>'],
#   ['DT', 'NP|<NNP-CD>'],
#   ['DT', 'NP|<JJ-NN-NN-SBAR>'],
#   ['DT', 'NP|<NNP-NN-NN-CC-NN-NN>'],
#   ['CD', 'NP|<,-CD-,-CD-,-CD-,-CD-,-CD-CC-CD>'],
#   ['PRP$', 'NP|<NNS-CC-NN-NN>'],
#   ['DT', 'NP|<JJ-CD-NNS-QP>'],
#   ['NP', 'NP|<PP-PP-PP-,-ADVP>'],
#   ['NNP', 'NP|<NN-NNP-NNP>'],
#   ['JJR', 'NP|<NN-NN>'],
#   ['NP', "NP|<PP-''-PP-SBAR>"],
#   ['DT', 'NP|<``-NN-NN>'],
#   ['PRP$', 'NP|<NNP-CD-JJ-NN>'],
#   ['NP', 'NP|<,-NP-,-ADJP-,>'],
#   ['NP', 'NP|<VP-SBAR-,>'],
#   ['QP', 'NP|<PRP$-NN-NN>'],
#   ['PRP$', 'NP|<NN-CC-NN-NNS>'],
#   ['PRP$', 'NP|<JJ-JJ-NNS-NN>'],
#   ['CD', 'NP|<NN-NNS-NNS>'],
#   ['PRP$', 'NP|<UCP-NN>'],
#   ['DT', 'NP|<JJ-NNP-NN-NNS>'],
#   ['PRP$', 'NP|<VBN-NN>'],
#   ['DT', 'NP|<NNS-CC-NN>'],
#   ['PRP$', 'NP|<NNP-NNP-JJ-VBN-NN>'],
#   ['DT', 'NP|<JJ-NNP-NN-POS>'],
#   ['JJ', "NP|<``-NN-''>"],
#   ['NP', 'NP|<,-ADVP-NP>'],
#   ['NNS', 'NP|<,-CC-RB-NNS>'],
#   ['NP', 'NP|<PP-,-PP-,>'],
#   ['NNP', 'NP|<IN-NNP>'],
#   ['JJS', 'NNPS'],
#   ['DT', 'NP|<RB-JJ-NN>'],
#   ['``', "NP|<NP-PP-''-PP>"],
#   ['NP', 'NP|<,-PP-,-SBAR>'],
#   ['DT', 'NP|<NNS-RB>'],
#   ['NP', "NP|<``-S-''>"],
#   ['PRP$', 'NP|<NNP-CD-NN>'],
#   ['DT', "NP|<``-NN-NN-''>"],
#   ['NP', 'NP|<,-RB-S>'],
#   ['NP', 'NP|<``-S>'],
#   ['PRP$', 'NP|<NNP-CD-NN-NN>'],
#   ['NP', 'NP|<NNP-.--LRB--NNP--RRB--NNP>'],
#   'PRP$',
#   ['PDT', 'NP|<DT-NN-NN>'],
#   ['NNPS', 'NNPS'],
#   ['DT', 'NP|<JJ-NNS-NNS>'],
#   ['NP', 'NP|<PP-,-NP>'],
#   ['NNP', 'NP|<CC-NNP-NNP-NNP>'],
#   ['NN', 'NP|<CC-JJ-NNS>'],
#   ['NNP', 'NP|<NNP-NNP-NNP-,-PP-,>'],
#   ['ADVP', 'NN'],
#   ['``', "NP|<NP-,-''-SBAR>"],
#   ['NP', 'NP|<,-NP-,-SBAR-,>'],
#   ['DT', 'NP|<JJ-NN-CC-NN>'],
#   ['NP', 'NP|<NNS-NNS>'],
#   ['DT', 'NP|<NNP-CD-NN-NN>'],
#   ['NP', 'NP|<CC-NP-NX-POS>'],
#   ['NP', 'NP|<,-NP-NP>'],
#   ['NNP', 'NP|<NNP-NNP-NNP-NNS>'],
#   ['JJ', 'NP|<NN-NNS-NN>'],
#   ['DT', 'NP|<NNP-CC-NNP-NN-NNS>'],
#   ['DT', 'NP|<JJ-JJ>'],
#   ['NP', 'NP|<VBG-NN-NNS>'],
#   ['DT', 'NP|<JJ-NNP-NNS-NNS>'],
#   ['ADVP', 'NP|<NP-CC-NP>'],
#   ['CC', 'NP|<DT-NNP-CC-NNP-NN-NN-NNS>'],
#   ['NP', 'NP|<NNP-NNP-NN>'],
#   ['NP+QP', 'NP|<PRN-PP>'],
#   ['NNP', 'NP|<NNP-JJ-NNS>'],
#   ['DT', 'NP|<NNP-NNP-NNP-JJ-NN-NN-NN>'],
#   ['DT', 'NP|<NNP-NNS-NN>'],
#   ['DT', 'NP|<NNP-NNP-NNP-NNPS-NNP>'],
#   ['DT', 'NP|<CD-JJ-NN-NN>'],
#   ['DT', "NP|<NNP-``-NNS-''-NN>"],
#   ['NP', 'NP|<,-PP-PP-,>'],
#   ['PRP$', 'NP|<JJ-NN-S>'],
#   ['ADVP', 'NP|<DT-JJ-NNP-NN-NN>'],
#   ['DT', "NP|<JJ-NN-``-NN-''-NN>"],
#   ['IN', 'NNP'],
#   ['DT', 'NP|<ADJP-NNP-NNP-NN>'],
#   ['NN', 'NP|<NN-NN-NN>'],
#   ['NN', 'NP|<NN-CC-VBG-NN>'],
#   ['NN', 'NP|<NNS-NN>'],
#   ...],
#  'NNP': ['Pierre',
#   'Vinken',
#   'Nov.',
#   'Mr.',
#   'Elsevier',
#   'N.V.',
#   'Dutch',
#   'Rudolph',
#   'Agnew',
#   'Consolidated',
#   'Gold',
#   'Fields',
#   'PLC',
#   'Kent',
#   'Lorillard',
#   'Inc.',
#   'Loews',
#   'Corp.',
#   'New',
#   'England',
#   'Journal',
#   'Medicine',
#   'James',
#   'A.',
#   'Talcott',
#   'Boston',
#   'Dana-Farber',
#   'Cancer',
#   'Institute',
#   'Dr.',
#   'National',
#   'Harvard',
#   'University',
#   'West',
#   'Groton',
#   'Mass.',
#   'Hollingsworth',
#   'Vose',
#   'Co.',
#   'U.S.',
#   'Brooke',
#   'T.',
#   'Mossman',
#   'Vermont',
#   'College',
#   'July',
#   'Environmental',
#   'Protection',
#   'Agency',
#   'Darrell',
#   'Phillips',
#   'IBC',
#   'Money',
#   'Fund',
#   'Report',
#   'Tuesday',
#   'August',
#   'Donoghue',
#   'Brenda',
#   'Malizia',
#   'Negus',
#   'Treasury',
#   'Monday',
#   'Dreyfus',
#   'World-Wide',
#   'Dollar',
#   'J.P.',
#   'Bolduc',
#   'W.R.',
#   'Grace',
#   'Terrence',
#   'D.',
#   'Daniels',
#   'Energy',
#   'Pacific',
#   'First',
#   'Financial',
#   'Royal',
#   'Trustco',
#   'Ltd.',
#   'Toronto',
#   'McDermott',
#   'International',
#   'Babcock',
#   'Wilcox',
#   'Bailey',
#   'Controls',
#   'Operations',
#   'Finmeccanica',
#   'S.p',
#   'Wickliffe',
#   'Ohio',
#   'Congress',
#   'House',
#   'Senate',
#   'Clark',
#   'J.',
#   'Vitulli',
#   'Mazda',
#   'Motor',
#   'Corp',
#   'Chrysler',
#   'Boca',
#   'Raton',
#   'Hot',
#   'Springs',
#   'Association',
#   'Manufacturers',
#   'Hoosier',
#   'Indianapolis',
#   'Rust',
#   'Belt',
#   'Du',
#   'Pont',
#   'Maytag',
#   'Trojan',
#   'Steel',
#   'Valley',
#   'Queen',
#   'Cheese',
#   'Factory',
#   'Mayor',
#   'William',
#   'H.',
#   'Hudnut',
#   'III',
#   'Symphony',
#   'Orchestra',
#   'Victor',
#   'Borge',
#   'Speedway',
#   'Fortune',
#   'Indiana',
#   'Roof',
#   'February',
#   'South',
#   'Korea',
#   'October',
#   'Wednesday',
#   'Trade',
#   'Industry',
#   'Ministry',
#   'January',
#   'Newsweek',
#   'Time',
#   'Washington',
#   'Post',
#   'Warner',
#   'Mortimer',
#   'B.',
#   'Zuckerman',
#   'News',
#   'World',
#   'Alan',
#   'Spoon',
#   'mid-October',
#   'Circulation',
#   'Credit',
#   'Plan',
#   'Publishers',
#   'Information',
#   'Bureau',
#   'Audit',
#   'Circulations',
#   'Electric',
#   'System',
#   'Public',
#   'Service',
#   'Hampshire',
#   'United',
#   'Illuminating',
#   'Northeast',
#   'Utilities',
#   'PS',
#   'Westborough',
#   'Haven',
#   'Conn.',
#   'Hartford',
#   'Conn',
#   'Manchester',
#   'N.H.',
#   'John',
#   'Rowe',
#   'Wilbur',
#   'Ross',
#   'Jr.',
#   'Rothschild',
#   'Federal',
#   'Regulatory',
#   'Commission',
#   'FERC',
#   'York',
#   'Stock',
#   'Exchange',
#   'Norman',
#   'Ricken',
#   'R',
#   'Us',
#   'Frederick',
#   'Deane',
#   'Signet',
#   'Banking',
#   'Daniel',
#   'M.',
#   'Rexinger',
#   'Circuit',
#   'City',
#   'Robert',
#   'R.',
#   'Glauber',
#   'Commonwealth',
#   'Edison',
#   'Illinois',
#   'Commerce',
#   'Judge',
#   'Richard',
#   'Curry',
#   'April',
#   'Feb.',
#   'Dec.',
#   'Byron',
#   'Rockford',
#   'Ill.',
#   'Supreme',
#   'Court',
#   'Appellate',
#   'Braidwood',
#   'LaSalle',
#   'I',
#   'Japan',
#   'Automobile',
#   'September',
#   'March',
#   'Texas',
#   'Chinchon',
#   'Seoul',
#   'Cray',
#   'Computer',
#   'Seymour',
#   'Research',
#   'Cray-3',
#   'May',
#   'Gregory',
#   'Barnum',
#   'Gary',
#   'P.',
#   'Smaby',
#   'Group',
#   'Minneapolis',
#   'SEC',
#   'Business',
#   'Hitachi',
#   'NEC',
#   'Fujitsu',
#   'Ltd',
#   'Nasdaq',
#   'Colorado',
#   'Colo.',
#   'Messrs.',
#   'Neil',
#   'Davenport',
#   'Joseph',
#   'Blanchard',
#   'Malcolm',
#   'Hammerton',
#   'Douglas',
#   'Wheeland',
#   'Stevens',
#   'Donald',
#   'Pardus',
#   'Arthur',
#   'Hatch',
#   'Eastern',
#   'Carney',
#   'Tassinari',
#   'Taiwan',
#   'Saudi',
#   'Arabia',
#   'China',
#   'Thailand',
#   'India',
#   'Brazil',
#   'Mexico',
#   'Representative',
#   'Carla',
#   'Hills',
#   'Mrs.',
#   'Taipei',
#   'Italy',
#   'Canada',
#   'Greece',
#   'Spain',
#   'Hoffman',
#   'Turkey',
#   'Malaysia',
#   'Argentina',
#   'Economy',
#   'Minister',
#   'Nestor',
#   'Rapanelli',
#   'Latin',
#   'American',
#   'Miguel',
#   'Alurralde',
#   'Assistant',
#   'Secretary',
#   'David',
#   'Mulford',
#   'Carlos',
#   'Carballo',
#   'President',
#   'Menem',
#   'The',
#   'Wall',
#   'Street',
#   'Apple',
#   'II',
#   'Commodore',
#   'Pet',
#   'Tandy',
#   'TRS-80',
#   'Stephen',
#   'Wozniak',
#   'Steven',
#   'Jobs',
#   'Homebrew',
#   'Club',
#   'Altair',
#   'Sol',
#   'IMSAI',
#   'Gates',
#   'Paul',
#   'Allen',
#   'IBM',
#   'F.',
#   'Shugart',
#   'Seagate',
#   'Technology',
#   'Dennis',
#   'Hayes',
#   'Dale',
#   'Heatherington',
#   'Atlanta',
#   'F.H.',
#   'Faulding',
#   'Moleculon',
#   'Kalipharma',
#   'Purepac',
#   'Australia',
#   'Bass',
#   'Strait',
#   'Whiting',
#   'Esso',
#   'Exxon',
#   'Broken',
#   'Hill',
#   'Pty.',
#   'Perch',
#   'Dolphin',
#   'Seahorse',
#   'Tarwhine',
#   'R.P.',
#   'Scherer',
#   'Southern',
#   'Optical',
#   'Thomas',
#   'Sloan',
#   'Shearson',
#   'Lehman',
#   'Hutton',
#   'White',
#   'Bush',
#   'Virgin',
#   'Timex',
#   'Generalized',
#   'Philippines',
#   'Magna',
#   'McAlpine',
#   'Frank',
#   'Stronach',
#   'Akerfeldt',
#   'Class',
#   'A',
#   'Parliament',
#   'Manfred',
#   'Gingl',
#   'Lord',
#   'Chilver',
#   'English',
#   'Clays',
#   'Mortgage',
#   'Fannie',
#   'Mae',
#   'O.',
#   'Maxwell',
#   'France',
#   'Hong',
#   'Kong',
#   'Blackstone',
#   'Goldman',
#   'Sachs',
#   'Daiwa',
#   'Co',
#   'London',
#   'L.',
#   'Pate',
#   'LTV',
#   'Bankruptcy',
#   'Code',
#   'Montedison',
#   'S.p.A.',
#   'Acquisition',
#   'Erbamont',
#   'November',
#   'Finance',
#   'Bank',
#   'June',
#   'Charles',
#   'E.',
#   'Simon',
#   'Chile',
#   'Austria',
#   'Portugal',
#   'Philippine',
#   'Corazon',
#   'Aquino',
#   'the',
#   'Big',
#   'Board',
#   'Guinea',
#   'George',
#   'Foot',
#   'Newgate',
#   'Management',
#   'Associates',
#   'Northampton',
#   'Mass',
#   'Michael',
#   'Porter',
#   'Smith',
#   'Barney',
#   'Harris',
#   'Upham',
#   'Oct.',
#   'Asia',
#   'Europe',
#   'Soviet',
#   'Union',
#   'Moscow',
#   'State',
#   'Department',
#   'Foreign',
#   'Economic',
#   'Affairs',
#   'Kerensky',
#   'Johnson',
#   'Debt',
#   'Default',
#   'Act',
#   'Monetary',
#   'U.S.S.R.',
#   'War',
#   'Purchasing',
#   'Kenneth',
#   'Mayland',
#   'Society',
#   'Cleveland',
#   'Reserve',
#   'Elliott',
#   'Platt',
#   'Donaldson',
#   'Lufkin',
#   'Jenrette',
#   'Securities',
#   'Berson',
#   'Bankers',
#   'Government',
#   'McGraw-Hill',
#   'F.W.',
#   'Dodge',
#   'Bretz',
#   'Pitney',
#   'Bowes',
#   'Stamford',
#   'Pamela',
#   'Sebastian',
#   'Haruki',
#   'Murakami',
#   'Wild',
#   'Sheep',
#   'Chase',
#   'Kodansha',
#   'Salty',
#   'Dogs',
#   'Johnny',
#   'Goode',
#   'Bugs',
#   'Bunny',
#   'Mickey',
#   'Spillane',
#   'Groucho',
#   'Harpo',
#   'Stanford',
#   'God',
#   'Man',
#   'Norwegian',
#   'Wood',
#   'Beatles',
#   'Tokyo',
#   'Gotta',
#   'Have',
#   'Macmillan',
#   'Wa',
#   'Japanese',
#   'Giants',
#   'Tatsunori',
#   'Hara',
#   'Funny',
#   'Soho',
#   'Katzenstein',
#   'Sony',
#   'Luce',
#   'Fellowship',
#   'Walkman',
#   'Akio',
#   'Morita',
#   'Ms.',
#   'Kirkpatrick',
#   'Singapore',
#   'Siti',
#   'Zaharah',
#   'Sulaiman',
#   'No-Smoking',
#   'Week',
#   'Mara',
#   'Kuala',
#   'Lumpur',
#   'Backer',
#   'Spielvogel',
#   'Bates',
#   'Thai',
#   'Pramual',
#   'Sabhavasu',
#   'Bangkok',
#   'Central',
#   'Plaza',
#   'Hotel',
#   'Yasser',
#   'Arafat',
#   'Olympic',
#   'Committee',
#   'Palestine',
#   'Liberation',
#   'Organization',
#   'WAFA',
#   'Palestinian',
#   'PLO',
#   'Health',
#   'Tourism',
#   'Beijing',
#   'AIDS',
#   'People',
#   'Daily',
#   'PAP',
#   'Poland',
#   'Warsaw',
#   'Hungary',
#   'River',
#   'Danube',
#   'Nagymaros',
#   'Czechoslovakia',
#   'Prime',
#   'Miklos',
#   'Nemeth',
#   'Strindberg',
#   'Stockholm',
#   'Lighthouse',
#   'BRAMALEA',
#   'Scotia',
#   'McLeod',
#   'RBC',
#   'Dominion',
#   'Bramalea',
#   'Lane',
#   'Charlie',
#   'Chaplin',
#   'Steve',
#   'Martin',
#   'Little',
#   'Tramp',
#   'Purchase',
#   'Place',
#   'Artist',
#   'Sidewalk',
#   'Stories',
#   'Marc',
#   'Marder',
#   'Bill',
#   'Dill',
#   'Greenwich',
#   'Village',
#   'Sixth',
#   'Avenue',
#   'Cosmopolitan',
#   'Lights',
#   'Nicole',
#   'Alysia',
#   'Bowery',
#   'Mission',
#   'Claude',
#   'Chabrol',
#   'Story',
#   'Women',
#   'Marie-Louise',
#   'Giraud',
#   'Vichy',
#   'Resistance',
#   'Isabelle',
#   'Huppert',
#   'Marie',
#   'Latour',
#   'Old',
#   'Gringo',
#   'Fuentes',
#   'Mexican',
#   'Revolution',
#   'Peck',
#   'Video',
#   'Tip',
#   'Boeing',
#   'Seattle',
#   'Kawasaki',
#   'Heavy',
#   'Industries',
#   'Mitsubishi',
#   'Fuji',
#   'Napolitan',
#   'Jersey',
#   'Virginia',
#   'Dinkins',
#   'Republican',
#   'Giuliani',
#   'Roger',
#   'Ailes',
#   'Siegal',
#   'Shrum',
#   'Doak',
#   'Campaign',
#   'Peter',
#   'Powers',
#   'Lt.',
#   'Gov.',
#   'Wilder',
#   'Marshall',
#   'Coleman',
#   'Greer',
#   'Monticello',
#   'Jefferson',
#   'Bob',
#   'Goodman',
#   'Mark',
#   'Rozell',
#   'Mary',
#   'Rep.',
#   'Florio',
#   'Pinocchio',
#   'Jim',
#   'Courter',
#   'Squier',
#   'Salmore',
#   'Eagleton',
#   'Democrat',
#   "O'Connor",
#   'GOP',
#   'Nelson',
#   'Rockefeller',
#   'Chicago',
#   'Friday',
#   'Aug.',
#   'Southeast',
#   'Hormats',
#   'Investment',
#   'Drobnick',
#   'California',
#   'Graduate',
#   'School',
#   'European',
#   'Common',
#   'Market',
#   'Calder',
#   'Woodrow',
#   'Wilson',
#   'Internatonal',
#   'Princeton',
#   'Indonesia',
#   'Zealand',
#   'Asian',
#   'Brunei',
#   'Baker',
#   'Australian',
#   'Hawke',
#   'Farren',
#   'Chong-sik',
#   'Lee',
#   'Pennsylvania',
#   'Cathryn',
#   'Rice',
#   'Greenville',
#   'High',
#   'Germany',
#   'Nancy',
#   'Yeargin',
#   'Carolina',
#   'Education',
#   'Improvement',
#   'Walt',
#   'Haney',
# ...
#  'ADJP|<VBN-PP>': [['VBN', 'PP']],
#  'S|<NP-ADVP-VP>': [['NP', 'S|<ADVP-VP>']],
#  'NP|<JJ-ADJP-NN>': [['JJ', 'NP|<ADJP-NN>']],
#  'VP|<RB-ADVP-ADJP-ADVP>': [['RB', 'VP|<ADVP-ADJP-ADVP>']],
#  'VP|<ADVP-ADJP-ADVP>': [['ADVP', 'VP|<ADJP-ADVP>']],
#  'VP|<ADJP-ADVP>': [['ADJP', 'ADVP']],
#  'ADJP|<VBN-S>': [['VBN', 'S+VP']],
#  'NP|<JJ-NNPS>': [['JJ', 'NNPS']],
#  'VP|<ADVP-ADVP-S>': [['ADVP', 'VP|<ADVP-S>']],
#  'VP|<:-``-S>': [[':', 'VP|<``-S>']],
#  'VP|<PRT-S>': [['PRT', 'S+VP'], ['PRT', 'S']],
#  'VP|<``-ADJP-S>': [['``', 'VP|<ADJP-S>']],
#  'VP|<ADJP-S>': [['ADJP', 'S+VP']],
#  "VP|<''-SBAR>": [["''", 'SBAR']],
#  'NP|<JJ-JJ-NNP-NN>': [['JJ', 'NP|<JJ-NNP-NN>']],
#  'NP|<JJ-NNP-NN>': [['JJ', 'NP|<NNP-NN>']],
#  'PRN|<SBAR-,>': [['SBAR', ',']],
#  'VP|<NP-PP-,-SBAR>': [['NP', 'VP|<PP-,-SBAR>'], ['NP+NP', 'VP|<PP-,-SBAR>']],
#  'NX|<NNP-NNP>': [['NNP', 'NNP']],
#  'S|<,-ADVP-,-ADVP-VP-.>': [[',', 'S|<ADVP-,-ADVP-VP-.>']],
#  'S|<ADVP-,-ADVP-VP-.>': [['ADVP', 'S|<,-ADVP-VP-.>']],
#  'S|<,-ADVP-VP-.>': [[',', 'S|<ADVP-VP-.>']],
#  'VP|<NP-PP-,-NP>': [['NP+NP', 'VP|<PP-,-NP>'],
#   ['NP', 'VP|<PP-,-NP>'],
#   ['NP+NP+QP', 'VP|<PP-,-NP>']],
#  'NP|<DT-JJ>': [['DT', 'JJ']],
#  'NP|<,-ADJP>': [[',', 'ADJP']],
#  'ADJP|<RB-JJ-PP>': [['RB', 'ADJP|<JJ-PP>']],
#  "S|<SBARQ-''-NP-VP-.>": [['SBARQ', "S|<''-NP-VP-.>"]],
#  'SBARQ|<SQ-.>': [['SQ', '.'], ['SQ+VP', '.']],
#  'SQ': [['VBZ', 'VP'],
#   ['VBZ', 'SQ|<NP-ADVP-VP>'],
#   ['INTJ', 'SQ|<,-VBP-RB-NP-VP-.>'],
#   ['VBP', 'SQ|<NP-VP-.>'],
#   ['VBZ', 'PP'],
#   ['VBZ', 'NP'],
#   ['ADVP', 'SQ|<MD-NP-VP-.>'],
#   ['VBZ', 'SQ|<NP-ADJP>'],
#   ['VBP', 'SQ|<NP-ADVP-VP>'],
#   ['MD', 'SQ|<NP-VP>'],
#   ['CC', 'SQ|<MD-NP-VP-.>'],
#   ['VBP', 'SQ|<NP-VP>'],
#   ['VBP', 'SQ|<VP-ADJP>'],
#   ['CC', 'SQ|<VBZ-RB-NP-NP-.>'],
#   ['VBD', 'SQ|<RB-NP-VP>'],
#   ['VBZ', 'SQ|<NP-ADVP>'],
#   ['VBZ', 'SQ|<NP-VP>'],
#   ['``', 'SQ|<VBP-NP-VP-.>'],
#   ['VBD', "SQ|<``-NP-''-VP>"],
#   ['MD', 'SQ|<NP-ADVP-VP-.>'],
#   'FRAG',
#   ['VBP', 'SQ|<NP-RB-VP>']],
#  'VP|<ADVP-:-SBAR>': [['ADVP', 'VP|<:-SBAR>']],
#  'VP|<:-SBAR>': [[':', 'SBAR']],
#  'FRAG+ADVP': [['IN', 'DT']],
#  'NP|<NNP-NNP-NNP-POS>': [['NNP', 'NP|<NNP-NNP-POS>']],
#  "NP|<NP-''-SBAR>": [['NP', "NP|<''-SBAR>"]],
#  'VP|<VBN-PP-,-PP>': [['VBN', 'VP|<PP-,-PP>']],
#  'S|<NP-VP-:-S-.>': [['NP', 'S|<VP-:-S-.>']],
#  'S|<VP-:-S-.>': [['VP', 'S|<:-S-.>']],
#  "NP|<``-JJ-NN-''-NN>": [['``', "NP|<JJ-NN-''-NN>"]],
#  "NP|<JJ-NN-''-NN>": [['JJ', "NP|<NN-''-NN>"]],
#  'NP|<,-NNP-CC-NNP-NNP-NNP>': [[',', 'NP|<NNP-CC-NNP-NNP-NNP>']],
#  'NP|<NNP-CC-NNP-NNP-NNP>': [['NNP', 'NP|<CC-NNP-NNP-NNP>']],
#  'NP|<CC-NNP-NNP-NNP>': [['CC', 'NP|<NNP-NNP-NNP>']],
#  'NP|<NNS-SBAR>': [['NNS', 'SBAR']],
#  'VP|<NP-PP-PP-,-S>': [['NP', 'VP|<PP-PP-,-S>']],
#  'VP|<PP-PP-,-S>': [['PP', 'VP|<PP-,-S>']],
#  'NP|<NN-NN-NNS-NN>': [['NN', 'NP|<NN-NNS-NN>']],
#  'VP|<NP-PRN>': [['NP', 'PRN']],
#  'PP|<ADVP-RB-PP>': [['ADVP', 'PP|<RB-PP>']],
#  'PP|<RB-PP>': [['RB', 'PP']],
#  'NP|<NN-NNS-POS>': [['NN', 'NP|<NNS-POS>']],
#  'SINV|<,-VP-NP-.>': [[',', 'SINV|<VP-NP-.>']],
#  'VP|<PP-PP-S>': [['PP', 'VP|<PP-S>']],
#  'ADJP|<CD-NN>': [['CD', 'NN']],
#  'VP|<NP-ADVP-PP-SBAR>': [['NP', 'VP|<ADVP-PP-SBAR>']],
#  'VP|<ADVP-PP-SBAR>': [['ADVP+ADVP', 'VP|<PP-SBAR>'],
#   ['ADVP', 'VP|<PP-SBAR>']],
#  'ADVP+ADVP': [['RBR', 'RB'], 'RBR'],
#  'VP+PP': [['IN', 'NP'], ['TO', 'NP']],
#  'S|<,-S-CC-S>': [[',', 'S|<S-CC-S>']],
#  'S|<S-CC-S>': [['S', 'S|<CC-S>']],
#  "S|<,-NP-VP-.-''>": [[',', "S|<NP-VP-.-''>"]],
#  'VP|<RB-VBG-ADVP>': [['RB', 'VP|<VBG-ADVP>']],
#  'VP|<VBG-ADVP>': [['VBG', 'ADVP']],
#  'QP|<RB-DT>': [['RB', 'DT']],
#  'NP|<PP-PP-,-ADJP>': [['PP', 'NP|<PP-,-ADJP>']],
#  'NP|<PP-,-ADJP>': [['PP', 'NP|<,-ADJP>']],
#  "NP|<``-NX-''-PRN>": [['``', "NP|<NX-''-PRN>"]],
#  "NP|<NX-''-PRN>": [['NX+NP', "NP|<''-PRN>"]],
#  'NX+NP': [['DT', 'NP|<NNP-NNP-NNP>']],
#  "NP|<''-PRN>": [["''", 'PRN']],
#  'PRN|<NP-,-NP-,-NP--RRB->': [['NP', 'PRN|<,-NP-,-NP--RRB->']],
#  'PRN|<,-NP-,-NP--RRB->': [[',', 'PRN|<NP-,-NP--RRB->']],
#  'PRN|<NP-,-NP--RRB->': [['NP', 'PRN|<,-NP--RRB->']],
#  'PRN|<,-NP--RRB->': [[',', 'PRN|<NP--RRB->']],
#  'ADJP|<,-ADJP>': [[',', 'ADJP']],
#  "VP|<``-NP-''>": [['``', "VP|<NP-''>"]],
#  "VP|<NP-''>": [['NP', "''"]],
#  'VP|<ADVP-ADJP-S>': [['ADVP', 'VP|<ADJP-S>']],
#  "NP|<JJ-``-JJ-''-NN>": [['JJ', "NP|<``-JJ-''-NN>"]],
#  "S|<NP-''-VP>": [['NP', "S|<''-VP>"]],
#  "S|<''-VP>": [["''", 'VP']],
#  'VP|<RB-S>': [['RB', 'S+VP']],
#  'ADJP|<CC-ADJP>': [['CC', 'ADJP']],
#  'NP|<JJ-,-JJ-,-JJ-NN>': [['JJ', 'NP|<,-JJ-,-JJ-NN>']],
#  'NP|<,-JJ-,-JJ-NN>': [[',', 'NP|<JJ-,-JJ-NN>']],
#  'VP|<PRT-PP-PP-PP>': [['PRT', 'VP|<PP-PP-PP>']],
#  'WHNP|<JJ-NNS>': [['JJ', 'NNS']],
#  'VP|<PRN-NP>': [['PRN', 'NP']],
#  "NP|<NP-''-PRN>": [['NP', "NP|<''-PRN>"]],
#  'PRN|<S--RRB->': [['S', '-RRB-'], ['S+VP', '-RRB-']],
#  'QP|<IN-CD-CD>': [['IN', 'QP|<CD-CD>']],
#  'NP|<NNP-NNP-,>': [['NNP', 'NP|<NNP-,>']],
#  'NP|<NNP-,>': [['NNP', ',']],
#  'NP|<``-NN>': [['``', 'NN']],
#  'NP|<NNP-NN-NNP-NNP>': [['NNP', 'NP|<NN-NNP-NNP>']],
#  "NP|<,-NP-,-''>": [[',', "NP|<NP-,-''>"]],
#  "NP|<NP-,-''>": [['NP', "NP|<,-''>"]],
#  'NP|<``-JJ-,-JJ-,-JJ-NN>': [['``', 'NP|<JJ-,-JJ-,-JJ-NN>']],
#  "NP|<,-''>": [[',', "''"]],
#  'S|<ADVP-,-NP-VP>': [['ADVP', 'S|<,-NP-VP>']],
#  'FW': ['besuboru', 'de', 'Perestroika', 'etc.'],
#  'VP|<VBP-NP-PP>': [['VBP', 'VP|<NP-PP>']],
#  'S|<:-S-:-S-:-S>': [[':', 'S|<S-:-S-:-S>']],
#  'S|<S-:-S-:-S>': [['S', 'S|<:-S-:-S>']],
#  'S|<:-S-:-S>': [[':', 'S|<S-:-S>']],
#  'S|<S-:-S>': [['S', 'S|<:-S>']],
#  'VP|<PRN-SBAR>': [['PRN', 'SBAR'], ['PRN', 'SBAR+S']],
#  'PRN|<VP-:>': [['VP', ':']],
#  'S|<:-S>': [[':', 'S']],
#  'VP|<PP-PP-PRN>': [['PP', 'VP|<PP-PRN>']],
#  'FRAG+PP': [['IN', 'NP'], ['ADVP', 'PP|<IN-NP>']],
#  "S|<NP-''-VP-.>": [['NP', "S|<''-VP-.>"]],
#  "S|<''-VP-.>": [["''", 'S|<VP-.>']],
#  'VP|<RB-ADJP>': [['RB', 'ADJP']],
#  "NP|<NP-''-PRN-PP>": [['NP', "NP|<''-PRN-PP>"]],
#  "NP|<''-PRN-PP>": [["''", 'NP|<PRN-PP>']],
#  'NP|<PRN-PP>': [['PRN', 'PP']],
#  'VP|<PP-SBAR-:-PP>': [['PP', 'VP|<SBAR-:-PP>']],
#  'VP|<SBAR-:-PP>': [['SBAR', 'VP|<:-PP>']],
#  'VP|<:-PP>': [[':', 'PP']],
#  'ADJP|<,-ADJP-,-ADJP>': [[',', 'ADJP|<ADJP-,-ADJP>']],
#  'ADJP|<ADJP-,-ADJP>': [['ADJP', 'ADJP|<,-ADJP>']],
#  'VP|<NP-:-PP>': [['NP', 'VP|<:-PP>']],
#  'NP|<DT-ADJP-NNS>': [['DT', 'NP|<ADJP-NNS>']],
#  'PP|<:-JJ-PP>': [[':', 'PP|<JJ-PP>']],
#  'PP|<JJ-PP>': [['JJ', 'PP']],
#  'VP|<ADVP-ADJP-SBAR>': [['ADVP', 'VP|<ADJP-SBAR>']],
#  'SBAR|<,-SBAR-,-CC-SBAR>': [[',', 'SBAR|<SBAR-,-CC-SBAR>']],
#  'SBAR|<SBAR-,-CC-SBAR>': [['SBAR', 'SBAR|<,-CC-SBAR>']],
#  'NP|<DT-JJ-NN>': [['DT', 'NP|<JJ-NN>']],
#  'SBAR|<,-CC-SBAR>': [[',', 'SBAR|<CC-SBAR>']],
#  'NP|<JJ-,-JJ-JJ-NN>': [['JJ', 'NP|<,-JJ-JJ-NN>']],
#  'NP|<,-JJ-JJ-NN>': [[',', 'NP|<JJ-JJ-NN>']],
#  'ADJP|<VBG-PP>': [['VBG', 'PP']],
#  'VP+ADVP': ['RB'],
#  'ADJP|<CC-JJR>': [['CC', 'JJR']],
#  'NX|<,-NX-,-NX-,-NX-CC-NX>': [[',', 'NX|<NX-,-NX-,-NX-CC-NX>']],
#  'NX|<NX-,-NX-,-NX-CC-NX>': [['NX', 'NX|<,-NX-,-NX-CC-NX>']],
#  'NX|<,-NX-,-NX-CC-NX>': [[',', 'NX|<NX-,-NX-CC-NX>']],
#  'NX|<NX-,-NX-CC-NX>': [['NX', 'NX|<,-NX-CC-NX>']],
#  "NP|<``-NNP-NNP-''>": [['``', "NP|<NNP-NNP-''>"]],
#  "NP|<NNP-NNP-''>": [['NNP', "NP|<NNP-''>"]],
#  "NP|<NNP-''>": [['NNP', "''"]],
#  'NP|<NNP-NNP-NNP-NN-NN>': [['NNP', 'NP|<NNP-NNP-NN-NN>']],
#  'QP|<IN-CD-IN-CD>': [['IN', 'QP|<CD-IN-CD>']],
#  'QP|<CD-IN-CD>': [['CD', 'QP|<IN-CD>']],
#  'VP|<PP-NP-,-PP>': [['PP', 'VP|<NP-,-PP>']],
#  'NP|<NNP-NNP-NNP-NN-NN-NNP>': [['NNP', 'NP|<NNP-NNP-NN-NN-NNP>']],
#  'NP|<NNP-NNP-NN-NN-NNP>': [['NNP', 'NP|<NNP-NN-NN-NNP>']],
#  'NP|<NNP-NN-NN-NNP>': [['NNP', 'NP|<NN-NN-NNP>']],
#  'NP|<NN-NN-NNP>': [['NN', 'NP|<NN-NNP>']],
#  'VP|<VBZ-VP>': [['VBZ', 'VP']],
#  'NP|<NNP-POS-NNP>': [['NNP', 'NP|<POS-NNP>']],
#  'NP|<POS-NNP>': [['POS', 'NNP']],
#  'NP|<NP-NNS-CC-NN>': [['NP', 'NP|<NNS-CC-NN>']],
#  'NP|<NNS-CC-NN>': [['NNS', 'NP|<CC-NN>']],
#  'VP|<PP-VP>': [['PP', 'VP']],
#  "NP|<NP-,-''-PP>": [['NP', "NP|<,-''-PP>"]],
#  "NP|<,-''-PP>": [[',', "NP|<''-PP>"]],
#  'NP|<JJ-NN-NN-NNP>': [['JJ', 'NP|<NN-NN-NNP>']],
#  'S|<,-NP-PRN-VP-.>': [[',', 'S|<NP-PRN-VP-.>']],
#  'NP|<ADJP-NNP-NN>': [['ADJP', 'NP|<NNP-NN>'], ['ADJP+QP', 'NP|<NNP-NN>']],
#  'NP|<JJ-NNP-NNP-NN>': [['JJ', 'NP|<NNP-NNP-NN>']],
#  'NP|<,-ADJP-,-ADVP-PP>': [[',', 'NP|<ADJP-,-ADVP-PP>']],
#  'NP|<ADJP-,-ADVP-PP>': [['ADJP', 'NP|<,-ADVP-PP>']],
#  'NP|<,-ADVP-PP>': [[',', 'NP|<ADVP-PP>']],
#  'NP|<ADVP-PP>': [['ADVP', 'PP']],
#  "S|<NP-''-VP-:>": [['NP', "S|<''-VP-:>"]],
#  "S|<''-VP-:>": [["''", 'S|<VP-:>']],
#  'VP|<NP-NP-,-PP>': [['NP', 'VP|<NP-,-PP>']],
#  'NP|<PP-NP-PRN>': [['PP', 'NP|<NP-PRN>']],
#  'NP|<NP-PRN>': [['NP', 'PRN']],
#  'NP|<PRN-PP-,-ADVP>': [['PRN', 'NP|<PP-,-ADVP>']],
#  'NP|<PP-,-ADVP>': [['PP', 'NP|<,-ADVP>']],
#  "NP|<NP-,-''-NP>": [['NP', "NP|<,-''-NP>"]],
#  'NP|<NNP-IN-NNP>': [['NNP', 'NP|<IN-NNP>']],
#  'NP|<IN-NNP>': [['IN', 'NNP']],
#  "NP|<,-''-NP>": [[',', "NP|<''-NP>"]],
#  "NP|<''-NP>": [["''", 'NP']],
#  'S|<,-ADVP-,-NP-VP-.>': [[',', 'S|<ADVP-,-NP-VP-.>']],
#  'S|<ADVP-,-NP-VP-.>': [['ADVP', 'S|<,-NP-VP-.>']],
#  'SINV|<VP-NP-,-PP-.>': [['VP', 'SINV|<NP-,-PP-.>']],
#  'SINV|<NP-,-PP-.>': [['NP', 'SINV|<,-PP-.>']],
#  'SINV|<,-PP-.>': [[',', 'SINV|<PP-.>']],
#  'SINV|<PP-.>': [['PP', '.']],
#  "VP|<``-S-''-SBAR>": [['``', "VP|<S-''-SBAR>"]],
#  "VP|<S-''-SBAR>": [['S+VP', "VP|<''-SBAR>"]],
#  'VP|<NP-SBAR-ADVP>': [['NP', 'VP|<SBAR-ADVP>']],
#  'VP|<SBAR-ADVP>': [['SBAR', 'ADVP'], ['SBAR+S', 'ADVP']],
#  'PRN|<SBAR--RRB->': [['SBAR', '-RRB-']],
#  'SBAR|<WHADVP-S>': [['WHADVP', 'S']],
#  'VP|<PRT-PP-,-PP>': [['PRT', 'VP|<PP-,-PP>']],
#  'S|<NP-ADVP-VP-.--RRB->': [['NP+NP', 'S|<ADVP-VP-.--RRB->']],
#  'S|<ADVP-VP-.--RRB->': [['ADVP', 'S|<VP-.--RRB->']],
#  'VP|<RB-NP-:-NP>': [['RB', 'VP|<NP-:-NP>']],
#  'VP|<NP-:-NP>': [['NP', 'VP|<:-NP>']],
#  "S|<,-SBAR-,-''-NP-VP-.>": [[',', "S|<SBAR-,-''-NP-VP-.>"]],
#  "S|<SBAR-,-''-NP-VP-.>": [['SBAR', "S|<,-''-NP-VP-.>"]],
#  'NP|<PRN-,-SBAR-,>': [['PRN', 'NP|<,-SBAR-,>']],
#  'VP|<VBZ-NP-PP>': [['VBZ', 'VP|<NP-PP>']],
#  'VP|<VB-NP>': [['VB', 'NP']],
#  'NP|<JJ-NP-NN>': [['JJ', 'NP|<NP-NN>']],
#  'NP|<NP-NN>': [['NP', 'NN']],
#  'NP|<JJ-DT-NN>': [['JJ', 'NP|<DT-NN>']],
#  'VP|<RB-NP-PP>': [['RB', 'VP|<NP-PP>']],
#  'NP|<JJ-NN-NN-NNP-NNP>': [['JJ', 'NP|<NN-NN-NNP-NNP>']],
#  'NP|<``-NX>': [['``', 'NX']],
#  'SBAR|<,-S>': [[',', 'S']],
#  'S|<,-VP>': [[',', 'VP']],
#  'PP|<PP-CC-PP>': [['PP', 'PP|<CC-PP>']],
#  'NP|<NNP-NN-POS>': [['NNP', 'NP|<NN-POS>']],
#  'VP|<CC-,-VP>': [['CC', 'VP|<,-VP>']],
#  'VP|<,-VP>': [[',', 'VP']],
#  'VP|<VBD-NP>': [['VBD', 'NP']],
#  'ADJP|<CC-JJ-PP>': [['CC', 'ADJP|<JJ-PP>']],
#  'S|<,-S-:-S-.>': [[',', 'S|<S-:-S-.>']],
#  'PRN|<VP--RRB->': [['VP', '-RRB-']],
#  'VP|<CC-VBG-S>': [['CC', 'VP|<VBG-S>']],
#  "S|<,-''-VP>": [[',', "S|<''-VP>"]],
#  'QP|<CD-NN-CC-CD-NN>': [['CD', 'QP|<NN-CC-CD-NN>']],
#  'QP|<NN-CC-CD-NN>': [['NN', 'QP|<CC-CD-NN>']],
#  'QP|<CC-CD-NN>': [['CC', 'QP|<CD-NN>']],
#  'QP|<CD-NN>': [['CD', 'NN']],
#  'NP|<JJR-CD>': [['JJR', 'CD']],
#  'S|<,-PP-,-VP>': [[',', 'S|<PP-,-VP>']],
#  'S|<PP-,-VP>': [['PP', 'S|<,-VP>']],
#  'NP|<CD-VBG-JJ-NNS>': [['CD', 'NP|<VBG-JJ-NNS>']],
#  'NP|<PP-,-ADJP-,>': [['PP', 'NP|<,-ADJP-,>']],
#  "S|<ADVP-,-''-PRN-``-NP-VP-.-''>": [['ADVP', "S|<,-''-PRN-``-NP-VP-.-''>"]],
#  "S|<,-''-PRN-``-NP-VP-.-''>": [[',', "S|<''-PRN-``-NP-VP-.-''>"]],
#  "S|<''-PRN-``-NP-VP-.-''>": [["''", "S|<PRN-``-NP-VP-.-''>"]],
#  "S|<PRN-``-NP-VP-.-''>": [['PRN', "S|<``-NP-VP-.-''>"]],
#  "S|<``-NP-VP-.-''>": [['``', "S|<NP-VP-.-''>"]],
#  'ADVP|<,-RB-CC-RB>': [[',', 'ADVP|<RB-CC-RB>']],
#  'ADVP|<RB-CC-RB>': [['RB', 'ADVP|<CC-RB>']],
#  'VP|<,-VP-CC-VP-,>': [[',', 'VP|<VP-CC-VP-,>']],
#  'VP|<VP-CC-VP-,>': [['VP', 'VP|<CC-VP-,>']],
#  'VP|<CC-VP-,>': [['CC', 'VP|<VP-,>']],
#  'VP|<VP-,>': [['VP', ',']],
#  "S|<S-,-''-PRN-S-,-CC-,-S-.>": [['S+VP', "S|<,-''-PRN-S-,-CC-,-S-.>"]],
#  "S|<,-''-PRN-S-,-CC-,-S-.>": [[',', "S|<''-PRN-S-,-CC-,-S-.>"]],
#  "S|<''-PRN-S-,-CC-,-S-.>": [["''", 'S|<PRN-S-,-CC-,-S-.>']],
#  'S|<PRN-S-,-CC-,-S-.>': [['PRN', 'S|<S-,-CC-,-S-.>']],
#  'S|<S-,-CC-,-S-.>': [['S', 'S|<,-CC-,-S-.>']],
#  'S|<,-CC-,-S-.>': [[',', 'S|<CC-,-S-.>']],
#  'S|<CC-,-S-.>': [['CC', 'S|<,-S-.>']],
#  'S|<,-S-.>': [[',', 'S|<S-.>']],
#  "S|<,-PP-,-NP-VP-.-''>": [[',', "S|<PP-,-NP-VP-.-''>"]],
#  "S|<PP-,-NP-VP-.-''>": [['PP', "S|<,-NP-VP-.-''>"]],
#  'VP|<RB-ADVP-VP>': [['RB', 'VP|<ADVP-VP>']],
#  'PRN|<ADVP-,>': [['ADVP', ',']],
#  'NP|<NNP-NNP-:>': [['NNP', 'NP|<NNP-:>']],
#  'NP|<NNP-:>': [['NNP', ':']],
#  'S|<ADVP-NP-ADVP-VP-.>': [['ADVP', 'S|<NP-ADVP-VP-.>']],
#  "S|<PRN-ADVP-VP-.-''>": [['PRN', "S|<ADVP-VP-.-''>"]],
#  "S|<ADVP-VP-.-''>": [['ADVP', "S|<VP-.-''>"], ['ADVP+ADVP', "S|<VP-.-''>"]],
#  "SBARQ|<NP-PRN-``-WHADVP-SQ-.-''>": [['NP', "SBARQ|<PRN-``-WHADVP-SQ-.-''>"]],
#  "SBARQ|<PRN-``-WHADVP-SQ-.-''>": [['PRN', "SBARQ|<``-WHADVP-SQ-.-''>"]],
#  "PRN|<''-SINV-,>": [["''", 'PRN|<SINV-,>']],
#  "SBARQ|<``-WHADVP-SQ-.-''>": [['``', "SBARQ|<WHADVP-SQ-.-''>"]],
#  "SBARQ|<WHADVP-SQ-.-''>": [['WHADVP', "SBARQ|<SQ-.-''>"]],
#  "SBARQ|<SQ-.-''>": [['SQ', "SBARQ|<.-''>"], ['SQ+VP', "SBARQ|<.-''>"]],
#  'SQ|<NP-ADVP-VP>': [['NP', 'SQ|<ADVP-VP>']],
#  'SQ|<ADVP-VP>': [['ADVP', 'VP']],
#  "SBARQ|<.-''>": [['.', "''"]],
#  "NP|<JJ-NNS-,-''>": [['JJ', "NP|<NNS-,-''>"]],
#  "NP|<NNS-,-''>": [['NNS', "NP|<,-''>"]],
#  "NP|<PRN-``-VP-.-''>": [['PRN+SINV', "NP|<``-VP-.-''>"]],
#  'PRN+SINV': [['VP', 'NP']],
#  "NP|<``-VP-.-''>": [['``', "NP|<VP-.-''>"]],
#  "NP|<VP-.-''>": [['VP', "NP|<.-''>"]],
#  "NP|<.-''>": [['.', "''"]],
#  "FRAG|<NP-PRN-``-S-.-''>": [['NP', "FRAG|<PRN-``-S-.-''>"]],
#  "FRAG|<PRN-``-S-.-''>": [['PRN', "FRAG|<``-S-.-''>"]],
#  "FRAG|<``-S-.-''>": [['``', "FRAG|<S-.-''>"]],
#  "FRAG|<S-.-''>": [['S', "FRAG|<.-''>"]],
#  'NP|<DT-NNS>': [['DT', 'NNS']],
#  "FRAG|<.-''>": [['.', "''"]],
#  'NP|<:-IN-NN-.>': [[':', 'NP|<IN-NN-.>']],
#  'NP|<IN-NN-.>': [['IN', 'NP|<NN-.>']],
#  'NP|<NN-.>': [['NN', '.']],
#  'ADJP|<CC-RB-ADVP-ADJP>': [['CC', 'ADJP|<RB-ADVP-ADJP>']],
#  'ADJP|<RB-ADVP-ADJP>': [['RB', 'ADJP|<ADVP-ADJP>']],
#  'ADJP|<ADVP-ADJP>': [['ADVP', 'ADJP']],
#  'VP|<VBD-NP-SBAR>': [['VBD', 'VP|<NP-SBAR>']],
#  "NP|<``-NN-''>": [['``', "NP|<NN-''>"]],
#  'S|<PRN-NP-VP-.>': [['PRN', 'S|<NP-VP-.>']],
#  'S|<PRN-``-VP-.>': [['PRN', 'S|<``-VP-.>']],
#  'VP|<ADJP-,-SBAR>': [['ADJP', 'VP|<,-SBAR>']],
#  'NP|<VP-SBAR>': [['VP', 'SBAR'], ['VP', 'SBAR+S+VP']],
#  'NP|<NN-FW-NN>': [['NN', 'NP|<FW-NN>']],
#  'NP|<FW-NN>': [['FW', 'NN']],
#  'NP|<``-JJ-NN>': [['``', 'NP|<JJ-NN>']],
#  "S|<,-SBAR-,-NP-VP-.-''>": [[',', "S|<SBAR-,-NP-VP-.-''>"]],
#  "S|<SBAR-,-NP-VP-.-''>": [['SBAR', "S|<,-NP-VP-.-''>"]],
#  'PRN|<SBAR-:>': [['SBAR', ':']],
#  "VP|<PRT-NP-``-PP-,-''>": [['PRT', "VP|<NP-``-PP-,-''>"]],
#  "VP|<NP-``-PP-,-''>": [['NP', "VP|<``-PP-,-''>"]],
#  "VP|<``-PP-,-''>": [['``', "VP|<PP-,-''>"]],
#  "VP|<PP-,-''>": [['PP', "VP|<,-''>"]],
#  "VP|<,-''>": [[',', "''"]],
#  "VP|<,-``-SQ-''>": [[',', "VP|<``-SQ-''>"]],
#  "VP|<``-SQ-''>": [['``', "VP|<SQ-''>"]],
#  "VP|<SQ-''>": [['SQ', "''"]],
#  'INTJ': [['VB', 'INTJ|<,-RB>'],
#   'RB',
#   ['NN', 'INTJ|<,-NN-,-NN-,-NN-,-NN-,-NN>'],
#   'UH',
#   ['RB', 'JJ'],
#   'VB'],
#  'INTJ|<,-RB>': [[',', 'RB']],
#  'SQ|<,-VBP-RB-NP-VP-.>': [[',', 'SQ|<VBP-RB-NP-VP-.>']],
#  'SQ|<VBP-RB-NP-VP-.>': [['VBP', 'SQ|<RB-NP-VP-.>']],
#  'SQ|<RB-NP-VP-.>': [['RB', 'SQ|<NP-VP-.>']],
#  'SQ|<NP-VP-.>': [['NP', 'SQ|<VP-.>']],
#  'SQ|<VP-.>': [['VP', '.']],
#  'UCP|<CC-ADJP>': [['CC', 'ADJP']],
#  "S|<NP-,-VP-.-''>": [['NP', "S|<,-VP-.-''>"]],
#  "S|<,-VP-.-''>": [[',', "S|<VP-.-''>"]],
#  "S|<,-''-CC-S-.>": [[',', "S|<''-CC-S-.>"]],
#  "S|<''-CC-S-.>": [["''", 'S|<CC-S-.>']],
#  'PRN|<ADJP-:>': [['ADJP', ':']],
#  "SINV|<S-.-''-VP-NP-.>": [['S+VP', "SINV|<.-''-VP-NP-.>"]],
#  "SINV|<.-''-VP-NP-.>": [['.', "SINV|<''-VP-NP-.>"]],
#  'S|<ADVP-NP-VP-.>': [['ADVP', 'S|<NP-VP-.>']],
#  "S|<,-CC-S-.-''>": [[',', "S|<CC-S-.-''>"]],
#  'VP|<,-``-FRAG>': [[',', 'VP|<``-FRAG>']],
#  'VP|<``-FRAG>': [['``', 'FRAG']],
#  'NP|<PRN-NN>': [['PRN', 'NN']],
#  'FRAG|<:-S>': [[':', 'S']],
#  'S|<,-PRN-,-VP>': [[',', 'S|<PRN-,-VP>']],
#  'S|<PRN-,-VP>': [['PRN+SINV', 'S|<,-VP>']],
#  "SINV|<SBARQ-.-''-VP-NP-.>": [['SBARQ', "SINV|<.-''-VP-NP-.>"]],
#  "PRN|<''-S-,>": [["''", 'PRN|<S-,>']],
#  'SBAR|<``-S>': [['``', 'S'], ['``', 'S+VP']],
#  'SBARQ|<S-.>': [['S+VP', '.']],
#  "VP|<``-ADJP-''-SBAR>": [['``', "VP|<ADJP-''-SBAR>"]],
#  "VP|<ADJP-''-SBAR>": [['ADJP', "VP|<''-SBAR>"]],
#  'PP|<NP-NP>': [['NP', 'NP'], ['NP+QP', 'NP']],
#  'NP|<CD-,-CD>': [['CD', 'NP|<,-CD>']],
#  'NP|<,-CD>': [[',', 'CD']],
#  'NP|<NN-PP>': [['NN', 'PP']],
#  ...}

# %% [markdown]
# # Part 2

# %% [markdown]
# A function called uniform() that takes a CFG stored as a dictionary and assigns uniform probabilities to all its rules. Do this by replacing the expansions with
# lists containing the expansion as the first element and its probability as the second.

# %%
def uniform(grammar):
  for key, value in grammar.items():
        if isinstance(value, list):
            total_expansions = len(value)
            probability = 1.0 / total_expansions
            for i, item in enumerate(value):
                    grammar[key][i] = [item, probability]

# grammar
grammar = {
    "NP": [["D", "N"], "cats", "dogs"],
    "VP": [["V", "NP"], "walk", "sleep"],
    "S": [["NP", "VP"]],
    "D": ["the", "a"],
    "N": ["cat", "dog"],
    "V": ["love", "tolerate"]
    }

  ### OUTPUT CHECK###
uniform(grammar)
grammar
# Out:
# {'NP': [[['D', 'N'], 0.3333333333333333],
#   ['cats', 0.3333333333333333],
#   ['dogs', 0.3333333333333333]],
#  'VP': [[['V', 'NP'], 0.3333333333333333],
#   ['walk', 0.3333333333333333],
#   ['sleep', 0.3333333333333333]],
#  'S': [[['NP', 'VP'], 1.0]],
#  'D': [['the', 0.5], ['a', 0.5]],
#  'N': [['cat', 0.5], ['dog', 0.5]],
#  'V': [['love', 0.5], ['tolerate', 0.5]]}

# %% [markdown]
# A function called pcky() that implements a probabilistic version of CKY algorithm. It takes two arguments: words, a list of strings representing a sequence of words, and grammar, a probabilistic CFG stored as a dictionary.

# %%
import math

def pcky(words, grammar):
	#initiate the 5*6 table
  table = [[[] for _ in range(len(words) + 1)] for _ in range(len(words))]

  for j in range(1, len(words) + 1):
        for key, value in grammar.items():
            for c in value:
                if words[j - 1] == c[0]:
                    table[j - 1][j].append({key: math.log(c[1])})


        for i in range(j - 2, -1, -1):
            for k in range(i + 1, j):
                for d in table[i][k]:
                    for key_1, value_1 in d.items():
                        a = key_1
                        p_ik = value_1
                    for e in table[k][j]:
                        for key_2, value_2 in e.items():
                            b = key_2
                            p_kj = value_2
                            combination = []
                            combination.append(a)
                            combination.append(b)
                            p = p_ik + p_kj

                            for key_3, value_3 in grammar.items():
                                for f in value_3:
                                    if combination == f[0]:
                                        table[i][j].append({key_3: math.log(f[1]) + p})


  tell_S = False
  max_value = None
  for h in table[0][j]:
        if 'S' in h:
            if not tell_S:
                tell_S = True
                max_value = h['S']
            else:
                if h['S'] >= max_value:
                    max_value = h['S']

  if not tell_S:
        return False
  else:
        return max_value

### OUTPUT CHECK###
#words
words = ['the', 'cat', 'tolerate', 'a', 'dog']

###dictionary
grammar = {
    "NP": [["D", "N"], "cats", "dogs"],
    "VP": [["V", "NP"], "walk", "sleep"],#
    "S": [["NP", "VP"]],
    "D": ["the", "a"],
    "N": ["cat", "dog"],
    "V": ["love", "tolerate"]
}
uniform(grammar)
print(pcky(words, grammar))
# Out:
# -6.761572768804056

# %% [markdown]
# # Part 3

# %% [markdown]
# Use pos files to estimate the parameters of an HMM.

# %%
# wsj_0XXX.pos files are available in tagged.zip
A = {}
B = {}
Π = {}

import collections
tag_list = []
word_list = []
lines_string = ""
all_tags = set()


file_paths = ["wsj_{:04d}.pos".format(i) for i in range(1, 200)]

for file_path in file_paths:
    prev_tag = ""
    with open(file_path, "r") as file:
        for line in file:
            line = line.strip()
            line = line.replace("[", "").replace("]", "")
            if line.startswith("=") or not line:
                continue

            lines_string += line + " " 
        print(lines_string)


# parse the line
lines_string = lines_string.replace("./.", "./.😊")
lines = lines_string.split("😊")


for line in lines:
    if not line.strip():
        continue
    tokens = line.split()

    for i, token in enumerate(tokens):
        if "/" not in token:
            continue
        word, tag = token.rsplit("/", 1)
        tag_list.append(tag)
        word_list.append(word)
        all_tags.add(tag)


        # first word in the sentence
        if i == 0:
            if tag in Π:
                Π[tag] += 1
            else:
                Π[tag] = 1
        else:
            # transition
            if prev_tag not in A:
                A[prev_tag] = {}
            if tag not in A[prev_tag]:
                A[prev_tag][tag] = 0
            A[prev_tag][tag] += 1

        # emission
        if tag not in B:
            B[tag] = {}
        if word not in B[tag]:
            B[tag][word] = 0
        B[tag][word] += 1

        prev_tag = tag

# Π
# Ensure Π includes all tags and normalize
for tag in all_tags:
    if tag not in Π:
        Π[tag] = 0

total = sum(Π.values())
if total != 0:
    for tag in Π:
        Π[tag] /= total
else:
    for tag in Π:
        Π[tag] = 0
total = sum(Π.values())
if total != 0:
    for tag in Π:
        Π[tag] /= total

# A
# Ensure A includes all tags and normalize
for tag in all_tags:
    if tag not in A:
        A[tag] = {}
    for tag_2 in all_tags:
      if tag_2 not in A[tag]:
        A[tag][tag_2] = 0

for a in A:
    total = sum(A[a].values())
    if total != 0:
      for b in A[a]:
        A[a][b] /= total
    else:
      for b in A[a]:
        A[a][b] = 0

# B
for tag in all_tags:
    if tag not in B:
        B[tag] = {}
    for word_2 in word_list:
      if word_2 not in B[tag]:
        B[tag][word_2] = 0

for q in B:
    total = sum(B[q].values())
    if total != 0:
      for o in B[q]:
        B[q][o] /= total
    else:
      for o in B[q]:
        B[q][o] = 0

# Print the results (optional)
print("Π:", Π)
print("A:", A)
print("B:", B)

#sanity check
tag_counts = collections.Counter(tag_list)
unique_tags = len(tag_counts)
word_counts = collections.Counter(word_list)
unique_words = len(word_counts)
print("-------sanity check-------")
print("tag_counts:", unique_tags)
print("word_counts:",unique_words)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Pick ten random sentences from the file sentences.txt and compare the probabilities assigned by the probabilistic CKY function to those of the Viterbi algorithm.

# %%
import math

def viterbi(A, B, Π, words):
  lattice = []
  for o in words:
      lattice.append({})
      for q in A:
        lattice[-1][q] = [float(0),'']

  # initialization step
  for q in A:
      if q in Π and words[0] in B[q]:
          lattice[0][q][0] = Π[q] * B[q][words[0]]

  # recursive step
  for t in range(1, len(words)):
      for qⱼ in A:
        max = float('0')
        pre = ''
        for qᵢ in A:
          p = lattice[t-1][qᵢ][0] * A[qᵢ][qⱼ] * B[qⱼ][words[t]]
          if p > max:
            max = p
            pre = qᵢ
        lattice[t][qⱼ] = [max, pre]


  path = []
  # find most prob state at time T
  max = float('-inf')
  end = ''
  for q in A:
      if lattice[-1][q][0] > max:
        max = lattice[-1][q][0]
        end = q

  path.append(end)
  backpoint = path[-1]
  for t in range(len(words) - 1, 0, -1):
      path.append(lattice[t][backpoint][1])
      backpoint = path[-1]

  return math.log(max)

### PCKY ###
### cfg grammar


grammar = cfg(open('rules.txt'))
uniform(grammar)


  ### OUTPUT ###
  # return the log likelihood of the most probable sequence of hidden states
  #return 'this is just a placeholder'
print("----------------viterbi output----------------")
sentences = [
    "Champagne and dessert followed .",
    "Pick a country , any country .",
    "The U.S.S.R. belongs to neither organization .",
    "Her alternative was 90 days in jail .",
    "South Korea has different concerns .",
    "Cathryn Rice could hardly believe her eyes .",
    "I believe in the system .",
    "`` I draw a blank . ''",
    "All came from Cray Research .",
    "`` That attracts attention ..."
]
for sentence in sentences:
    words = sentence.split()
    viterbi_log_prob = viterbi(A, B, Π, words)
    print(f"Sentence: {sentence}")
    print(f"Viterbi Log Probability: {viterbi_log_prob}")

print("------------------PCKY output------------------")
#words = "Champagne and dessert followed .".split()
#pcky(words, grammar)
for sentence in sentences:
    words = sentence.split()
    cky_results = pcky(words, grammar)
    print(f"Sentence: {sentence}")
    print(f"CKY Log Probability: {cky_results}")
# Out:
# ----------------viterbi output----------------
# Sentence: Champagne and dessert followed .
# Viterbi Log Probability: -37.21512016749909
# Sentence: Pick a country , any country .
# Viterbi Log Probability: -39.81856369746412
# Sentence: The U.S.S.R. belongs to neither organization .
# Viterbi Log Probability: -47.64210688061698
# Sentence: Her alternative was 90 days in jail .
# Viterbi Log Probability: -55.4426928761881
# Sentence: South Korea has different concerns .
# Viterbi Log Probability: -37.462421004740975
# Sentence: Cathryn Rice could hardly believe her eyes .
# Viterbi Log Probability: -61.70530527532861
# Sentence: I believe in the system .
# Viterbi Log Probability: -27.693944977995766
# Sentence: `` I draw a blank . ''
# Viterbi Log Probability: -33.24627894041153
# Sentence: All came from Cray Research .
# Viterbi Log Probability: -41.350183824060004
# Sentence: `` That attracts attention ...
# Viterbi Log Probability: -40.934838773238155
# ------------------PCKY output------------------
# Sentence: Champagne and dessert followed .
# CKY Log Probability: -43.275273025735025
# Sentence: Pick a country , any country .
# CKY Log Probability: -59.061454615414775
# Sentence: The U.S.S.R. belongs to neither organization .
# CKY Log Probability: -59.3251969022203
# Sentence: Her alternative was 90 days in jail .
# CKY Log Probability: -74.00153374106864
# Sentence: South Korea has different concerns .
# CKY Log Probability: -60.93992164375324
# Sentence: Cathryn Rice could hardly believe her eyes .
# CKY Log Probability: -75.57128889992995
# Sentence: I believe in the system .
# CKY Log Probability: -56.440245630308496
# Sentence: `` I draw a blank . ''
# CKY Log Probability: -53.07408474539902
# Sentence: All came from Cray Research .
# CKY Log Probability: -56.67553279802686
# Sentence: `` That attracts attention ...
# CKY Log Probability: -44.22445435844077

# %% [markdown]
# viterbi output：
#
# Sentence: Champagne and dessert followed .
#
# Viterbi Log Probability: -37.21512016749909
#
# Sentence: Pick a country , any country .
#
# Viterbi Log Probability: -39.81856369746412
#
# Sentence: The next province ?
#
# Viterbi Log Probability: -27.26323409053319
#
# Sentence: It 's imaginative and often funny .
#
# Viterbi Log Probability: -47.6282461439437
#
# Sentence: South Korea has different concerns .
#
# Viterbi Log Probability: -37.462421004740975
#
# Sentence: This is Japan ?
#
# Viterbi Log Probability: -28.254575976046777
#
# Sentence: Who 's telling the truth ?
#
# Viterbi Log Probability: -42.08550907397408
#
# Sentence: He was previously vice president .
#
# Viterbi Log Probability: -36.518522431980415
#
# Sentence: All came from Cray Research .
#
# Viterbi Log Probability: -41.350183824060004
#
# Sentence: He is his own man .
#
# Viterbi Log Probability: -31.55667294386035
#
# ------------------PCKY output------------------
#
# Sentence: Champagne and dessert followed .
#
# CKY Log Probability: -43.275273025735025
#
# Sentence: Pick a country , any country .
#
# CKY Log Probability: -59.061454615414775
#
# Sentence: The U.S.S.R. belongs to neither organization .
#
# CKY Log Probability: -59.3251969022203
#
# Sentence: Her alternative was 90 days in jail .
#
# CKY Log Probability: -74.00153374106864
#
# Sentence: South Korea has different concerns .
#
# CKY Log Probability: -60.93992164375324
#
# Sentence: Cathryn Rice could hardly believe her eyes .
#
# CKY Log Probability: -75.57128889992995
#
# Sentence: I believe in the system .
#
# CKY Log Probability: -56.440245630308496
#
# Sentence: `` I draw a blank . ''
#
# CKY Log Probability: -53.07408474539902
#
# Sentence: All came from Cray Research .
#
# CKY Log Probability: -56.67553279802686
#
# Sentence: `` That attracts attention ...
#
# CKY Log Probability: -44.22445435844077
#
#
# Results and Discussions:
#
# The results show that all sentences score higher likelihoods on Viterbi than PCKY.
#
# Properties Accounting for Differences between CKY and Viterbi (HMM):
#
# Using CKY and PCKY algorithm to obtain dependency parses of phrases/sentences, which is only possible if they obey given CFG rules. As a result, PCKY can capture complex syntactic dependencies better due to its use of a detailed probabilistic CFG derived from actual reasonable rules. However, it is greatly influenced by factors such as the shape of the trees, and labels of the tree. This typically leads to a more fine-grained partitioning of the training data. But it is very slow.
#
# Viterbi (HMM) deals with initial tags, tag/tag, and tag/word dependencies through state transitions and emissions. It is no necessary to think about syntax, but just focuses on the changing pattern of any two adjacent components. It yields higher log probabilities for sentences with straightforward dependencies.
#
# Conclusion：
# The probabilistic CKY algorithm is fine-grained but was outperformed by the Viterbi algorithm in time due to the latter’s efficiency in managing sequential data and local dependencies,

# %% [markdown]
# Use the file rules.txt to estimate the parameters of the probabilistic CFG. Compare the probabilities assigned by your probabilistic CKY function using this new grammar to those of the old grammar and those of the Viterbi algorithm.

# %%
new_grammar = {}

with open("rules.txt") as f:
    lhs_count = {}
    for line in f:
        line = line.strip()
        linespl = line.split("➡️")
        linespl[0] = linespl[0].strip()
        if "🦖" in linespl[1]:
            linespl[1] = [part.strip() for part in linespl[1].split("🦖")]
        else:
            linespl[1] = linespl[1].strip()

        a = linespl[0]
        b = linespl[1]

        if a not in lhs_count:
            lhs_count[a] = 0
        lhs_count[a] += 1

        if a not in new_grammar:
            new_grammar[a] = [[b, 1]]
        else:
            found = False
            for item in new_grammar[a]:
                if item[0] == b:
                    item[1] += 1
                    found = True
                    break
            if not found:
                new_grammar[a].append([b, 1])

for a in new_grammar:
    total = sum(item[1] for item in new_grammar[a])
    for item in new_grammar[a]:
        item[1] = item[1] / total

# Probabilistic CKY algorithm

sentences = [
    "Champagne and dessert followed .",
    "Pick a country , any country .",
    "The U.S.S.R. belongs to neither organization .",
    "Her alternative was 90 days in jail .",
    "South Korea has different concerns .",
    "Cathryn Rice could hardly believe her eyes .",
    "I believe in the system .",
    "`` I draw a blank . ''",
    "All came from Cray Research .",
    "`` That attracts attention ..."
]
for sentence in sentences:
    words = sentence.split()
    cky_results = pcky(words, new_grammar)
    print(f"Sentence: {sentence}")
    print(f"CKY Log Probability: {cky_results}")
# Out:
# {'S': [[['NP', 'S|<VP-.>'], 0.2742342911272498], [['S', 'S|<,-NP-VP-.>'], 0.017998105462582886], [['NP', 'VP'], 0.34101673508051783], [['SBAR', 'S|<,-NP-VP-.>'], 0.012946005683612252], [['NP', "S|<VP-.-''>"], 0.012472371329333754], [['PP', 'S|<,-NP-VP>'], 0.0058414903694347965], [['PP', 'S|<,-NP-VP-.>'], 0.04262709188506473], [['NP', 'S|<ADVP-VP>'], 0.013103883801705084], [['``', 'S|<CC-NP-VP-.>'], 0.00015787811809283233], [['ADVP', 'S|<PRN-NP-``-VP-.>'], 0.00015787811809283233], [['NP', 'S|<,-PP-,-VP-.>'], 0.0022102936532996525], [['ADVP', 'S|<,-NP-VP-.>'], 0.014998421218819072], [['S', 'S|<:-S-.>'], 0.006630880959898958], [['SBAR', 'S|<,-NP-VP>'], 0.005683612251341964], [['S', 'S|<,-CC-S-.>'], 0.01484054310072624], [['PP', 'S|<NP-VP-.>'], 0.0029996842437638145], [['SBAR', 'S|<,-NP-ADVP-VP-.>'], 0.000473634354278497], [['CC', 'S|<NP-VP-.>'], 0.01768234922639722], [['NP', 'S|<,-PP-,-NP-VP-.>'], 0.00031575623618566466], [['S', 'S|<,-IN-S-.>'], 0.00015787811809283233], [['ADVP', 'S|<,-PP-,-NP-VP-.>'], 0.000947268708556994], [['S+NP', 'S|<,-NP-VP-.>'], 0.0006315124723713293], [['NP', 'S|<,-NP-VP-.>'], 0.003946952952320808], [['S+VP', 'S|<,-NP-VP-.>'], 0.005209977897063467], [['CC', 'S|<PP-,-NP-VP-.>'], 0.0025260498894853173], [['NP', 'S|<,-S-,-VP-.>'], 0.0015787811809283233], [['S', 'S|<:-S-:-S-.>'], 0.00015787811809283233], [['PP', 'VP'], 0.0011051468266498263], [['S', 'S|<,-CC-S>'], 0.004420587306599305], [['SBAR', 'VP'], 0.000473634354278497], [['PP', 'S|<NP-VP>'], 0.0025260498894853173], [['S', 'S|<CC-S-S>'], 0.00015787811809283233], [['NP', 'ADVP'], 0.000473634354278497], [['ADVP', 'VP'], 0.009788443321755604], [['S', 'S|<CC-S-.>'], 0.0034733185980423114], [['S', 'S|<CC-S>'], 0.004262709188506473], [['``', 'S|<SBAR-,-S-,-CC-S-.>'], 0.00015787811809283233], [['S', "S|<,-''-NP-VP-.>"], 0.001894537417113988], [['NP', 'S|<ADVP-VP-.>'], 0.018787496053047047], [['ADVP', 'S|<,-SBAR-NP-VP>'], 0.00015787811809283233], [['``', 'S|<NP-VP-:>'], 0.00031575623618566466], [['NP', 'S|<,-VP-.>'], 0.000473634354278497], [['``', "S|<S-,-''-NP-VP-.>"], 0.011682980738869593], [['ADVP', 'S|<NP-VP>'], 0.0007893905904641617], [['NP', 'S|<:-VP>'], 0.00031575623618566466], [['S+VP', 'VP'], 0.0022102936532996525], [['PP', 'S|<NP-,-NP-VP-.>'], 0.0020524155352068204], [['NP', 'ADJP'], 0.005683612251341964], [['NP', 'S|<NP-VP-.>'], 0.0012630249447426586], [['``', 'S|<NP-VP-.>'], 0.0020524155352068204], [['NP', 'NP'], 0.0020524155352068204], [['``', "S|<S-CC-S-.-''>"], 0.00031575623618566466], [['NP', 'S|<RB-VP>'], 0.00015787811809283233], [['NP', 'S|<PP-S>'], 0.00015787811809283233], [['PP', 'S|<,-SBAR-,-NP-VP-.>'], 0.000473634354278497], [['ADVP', 'S|<NP-VP-.>'], 0.0020524155352068204], [['ADVP', 'S|<,-NP-VP>'], 0.002841806125670982], [['NP', 'S|<PRN-VP>'], 0.0006315124723713293], [['S+VP', 'S|<CC-S>'], 0.0007893905904641617], [['VP', 'PP'], 0.000473634354278497], [['-LRB-', 'S|<PP-,-NP-VP-.--RRB->'], 0.00015787811809283233], [['NP', 'S|<PRN-VP-.>'], 0.002841806125670982], [['S+ADJP', 'S|<,-NP-VP-.>'], 0.000473634354278497], [['CC', 'S|<NP-PRN-VP-.>'], 0.00015787811809283233], [['NP', 'S|<PP-VP>'], 0.0006315124723713293], [['NP', 'S|<,-NP-ADVP-VP-.>'], 0.00031575623618566466], [['NP', 'PP'], 0.0012630249447426586], [['PP', "S|<PRN-NP-VP-.-''>"], 0.00015787811809283233], [['VP', '.'], 0.0015787811809283233], [['NP+NP', 'S|<VP-.>'], 0.0036311967161351435], [['S', 'S|<:-SBARQ>'], 0.00015787811809283233], [['NP', 'S|<VP-,>'], 0.0007893905904641617], [['SBAR', 'S|<PRN-S-CC-S-.>'], 0.00015787811809283233], [['SBAR', 'S|<VP-.>'], 0.0007893905904641617], [['PP', 'S|<,-NP-ADVP-VP-.>'], 0.0017366592990211557], [['NP', 'S|<NP-VP>'], 0.0007893905904641617], [['CC', 'S|<NP-ADVP-VP>'], 0.00031575623618566466], [['NP+NP', 'VP'], 0.004104831070413641], [['ADJP', 'S|<,-NP-VP-.>'], 0.00031575623618566466], [['NP', 'S|<,-ADVP-,-ADVP-VP-.>'], 0.00031575623618566466], [['``', "S|<SBARQ-''-NP-VP-.>"], 0.00015787811809283233], [['``', "S|<NP-VP-.-''>"], 0.0050520997789706345] ...
# Sentence: Champagne and dessert followed .
# CKY Log Probability: -46.450120753484995
# Sentence: Pick a country , any country .
# CKY Log Probability: -43.32823271567303
# Sentence: The U.S.S.R. belongs to neither organization .
# CKY Log Probability: -48.85400389886128
# Sentence: Her alternative was 90 days in jail .
# CKY Log Probability: -59.45129216401506
# Sentence: South Korea has different concerns .
# CKY Log Probability: -36.94895088353458
# Sentence: Cathryn Rice could hardly believe her eyes .
# CKY Log Probability: -60.632716262781706
# Sentence: I believe in the system .
# CKY Log Probability: -45.843776759129376
# Sentence: `` I draw a blank . ''
# CKY Log Probability: -56.66603737007935
# Sentence: All came from Cray Research .
# CKY Log Probability: -50.64227371453571
# Sentence: `` That attracts attention ...
# CKY Log Probability: -54.25957020996016

# %% [markdown]
# ------------NEW_grammar PCKY results------------
#
# Sentence: Champagne and dessert followed .
#
# CKY Log Probability: -46.450120753484995
#
# Sentence: Pick a country , any country .
#
# CKY Log Probability: -43.32823271567303
#
# Sentence: The U.S.S.R. belongs to neither organization .
#
# CKY Log Probability: -48.85400389886128
#
# Sentence: Her alternative was 90 days in jail .
#
# CKY Log Probability: -59.45129216401506
#
# Sentence: South Korea has different concerns .
#
# CKY Log Probability: -36.94895088353458
#
# Sentence: Cathryn Rice could hardly believe her eyes .
#
# CKY Log Probability: -60.632716262781706
#
# Sentence: I believe in the system .
#
# CKY Log Probability: -45.843776759129376
#
# Sentence: `` I draw a blank . ''
#
# CKY Log Probability: -56.66603737007935
#
# Sentence: All came from Cray Research .
#
# CKY Log Probability: -50.64227371453571
#
# Sentence: `` That attracts attention ...
#
# CKY Log Probability: -54.25957020996016
#
#
# Results and discussion:
#
# Seven sentence, "Pick a country , any country .", "The U.S.S.R. belongs to neither organization .", "Her alternative was 90 days in jail .", "South Korea has different concerns .", "Cathryn Rice could hardly believe her eyes .", "I believe in the system .", "All came from Cray Research .", score a higher likelihood on new PCKY than old one. The new probabilistic grammar enhances probabilities compared to the old uniform probabilistic grammar. This improvement is due to the data-driven estimation of rule probabilities, which makes parsing more representative of actual language structures.
#
# Comparison with HMM (Viterbi), HMM still offers competitive log probabilities, which is higher than those of the new probabilistic CFG. This consistency arises from the HMM's ability to handle transitions and emissions probabilistically at each step. The new probabilistic CFG occasionally produces higher log probabilities than the HMM, indicating that the CFG can capture syntactic dependencies that the HMM might miss, particularly in cases involving complex syntactic structures.
